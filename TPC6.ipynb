# %% [markdown]
# ## TPC6
# ### 31 de outubro
# ### José Carlos Ramalho e Luís Cunha

# %% [markdown]
# ### Exercício 1: Processando um dataset em CSV
#
# Escreve um programa que lê o dataset `obras.csv` e realiza as seguintes tarefas (tenta isolar cada tarefa numa função):
# * Carrega o dataset para uma estrutura de dados pensada por ti;
# * Quantas obras existem catalogadas no dataset?
# * Imprime no monitor uma tabela com o título da obra, a sua descrição, o seu compositor e ano de criação;
# * Produz uma lista de tuplos `(título, ano)` ordenada alfabeticamente por título;
# * Produz uma lista de tuplos `(título, ano)` ordenada crescentemente por ano;
# * Produz uma lista ordenada dos compositores;
# * Calcula uma distribuição das obras por período;
# * Calcula uma distribuição das obras por ano;
# * Calcula uma distribuição das obras por compositor;
# * Especifica uma função que recebendo uma distribuição desenha o seu gráfico. Aplica-a às distribuições anteriores;
# * Problema da inversão estrutural: calcula uma estrutura de dados que corresponde a uma lista dos compositores em que cada compositor tem a ele associado uma lista dos títulos das obras que compôs;
# * Cria uma função de visualização para estrutura de dados calculada na alínea anterior.

# %%
# Solução do exercício 1
import aula6_2

# %%
obras= aula6_2.leObras("../ATP/obras.csv")

# %%
aula6_2.tamanhoObras(obras)
# Out:
# 174

# %%
aula6_2.imprime(obras)
# Out:
#  | Rage Over a Lost Pen | The "Rondo alla ingharese | 1745     | Krebs, Johann L
#  | Zärtliche Liebe      | "Zärtliche Liebe" (Tender | 1791     | Reincken, Johan
#  | Military Band No. 1  | The March for Military Ba | 1673     | Emanuele d'Asto
#  | The Rondo            | Ludwig van Beethoven wrot | 1744     | Sammartini, Gio
#  | Three Pieces for Orc | Alban Berg composed his T | 1470     | Nicolaus Bruhns
#  | Ab Irato             | Étude de perfectionnement | 1749     | Johann David He
#  | Adagio in B minor    | The Adagio in B minor for | 1418     | Durante, France
#  | Bagatelles, Opus 119 | The Eleven Bagatelles, Op | 1589     | Gregor Aichinge
#  | Bagatelles, Opus 33  | The Seven Bagatelles, Op. | 1551     | Samuel Scheidt
#  | Ballade No.1         | Ballade No. 1 in D flat m | 1370     | Marc-Antoine Ch
#  | Ballades, Op. 10     | The Ballades, Op. 10 are  | 1481     | Seixas, Carlos
#  | Bamboula, Op. 2      | Bamboula, Op. 2, is a fan | 1763     | Hasse, Johann A
#  | Barcarole Op. 60     | The Barcarole in F sharp  | 1423     | Melchior Schild
#  | Berceuse             | Frédéric Chopin's Berceus | 1972     | Johann Nicolaus
#  | Book II              | Variations on a Theme of  | 1855     | Monsieur de Sai
#  | Cantatas, BWV 141-15 | Uns ist ein Kind geboren  | 1634     | Sanz, Gaspar
#  | Capriccio Italien    | The Capriccio Italien, Op | 1795     | Weldon, John
#  | Carnival Overture    | The concert overture Carn | 1563     | Nivers, Guillau
#  | Coriolan Overture    | The Coriolan Overture (Ge | 1452     | Bach, Wilhelm F
#  | Czech Suite          | The Czech Suite in D majo | 1796     | Rousseau, Jean-
#  | Die Ideale, S.106    | Die Ideale, S. 106, is a  | 1663     | Mondonville, Je
#  | Dixit Dominus        | Dixit Dominus is a psalm  | 1453     | Caldara, Antoni
#  | Eleven Chorale Prelu | The Eleven Chorale Prelud | 1961     | Pergolesi, Giov
#  | Eroica Variations    | The Variations and Fugue  | 1431     | Henri Desmarets
#  | Estampes             | Estampes (Prints), L.100, | 1598     | Manuel Rodrigue
#  | Fantaisie brillante, | Fantaisie brillante sur d | 1551     | Giovanni Gabrie
#  | Fantasia and Fugue,  | The Great Fantasia and Fu | 1341     | Strozzi, Barbar
#  | Fantasia in D minor  | Fantasia No. 3 in D minor | 1442     | Marais, Marin
#  | Fantasy No. 2        | Fantasy No. 2 in C minor, | 1683     | Sammartini, Giu
#  | Fantasy No. 4        | Fantasy No. 4 in C minor, | 1864     | John Blow
#  | Fantasy on Hungarian | The Fantasia on Hungarian | 1495     | Carissimi, Giac
#  | Faust Overture       | The Faust Overture is a c | 1412     | Friederike Soph
#  | Festklänge, S.101    | Festklänge is the seventh | 1640     | Manuel Correia
#  | Feu d'artifice       | Feu d'artifice, Op. 4 (Fi | 1869     | Krebs, Johann L
#  | Feuilles d'Album     | Feuille d'Album (S.165) i | 1857     | Carissimi, Giac
#  | French Overture      | The Overture in the Frenc | 1810     | Pedro de Araujo
#  | Funeral March in Mem | Edvard Grieg composed his | 1602     | Carissimi, Giac
#  | Fürchte dich nicht   | Fürchte dich nicht (Fear  | 1975     | Johann Hermann
#  | Gigue in G major, K. | Kleine Gigue in G major,  | 1383     | Leopold I
#  | Grande Tarantelle    | Grande Tarantelle, Op. 67 | 1854     | Johann Christop
#  | Grande valse brillan | The Grande valse brillant | 1330     | Machado, Manuel
#  | Hamlet, S.104        | Hamlet, S.104, is a symph | 1565     | Peter Philips
#  | Hungarian Rhapsody N | Hungarian Rhapsody no. 10 | 1602     | Gregor Aichinge
#  | Hungarian Rhapsody N | Hungarian Rhapsody No. 11 | 1454     | Weldon, John
#  | Hungarian Rhapsody N | Hungarian Rhapsody No. 12 | 1522     | Froberger, Joha
#  | Hungarian Rhapsody N | Hungarian Rhapsody No. 13 | 1442     | Jean-Marie Lecl
#  | Hungarian Rhapsody N | Hungarian Rhapsody No. 14 | 1788     | Pietro Della Va
#  | Hungarian Rhapsody N | Hungarian Rhapsody No. 15 | 1302     | Dieterich Buxte
#  | Hungarian Rhapsody N | Hungarian Rhapsody No. 16 | 1706     | Neander, Joachi
#  | Hungarian Rhapsody N | Hungarian Rhapsody No. 17 | 1940     | Jean-Joseph Mou
#  | Hungarian Rhapsody N | Hungarian Rhapsody No. 18 | 1798     | Rousseau, Jean-
#  | Hungarian Rhapsody N | Hungarian Rhapsody No. 3, | 1354     | Caldara, Antoni
#  | Hungarian Rhapsody N | Hungarian Rhapsody No. 4, | 1377     | Georg Bohm
#  | Hungarian Rhapsody N | Hungarian Rhapsody No. 5, | 1743     | Bach, Wilhelm F
#  | Hungarian Rhapsody N | Hungarian Rhapsody No. 7, | 1485     | Baldassare Galu
#  | Hungarian Rhapsody N | Hungarian Rhapsody No. 8, | 1676     | Haym, Nicola Fr
#  | Hungarian Rhapsody N | Hungarian Rhapsody No. 9, | 1994     | Wilhelmine of P
#  | Hungarian Rhapsody N | Hungarian Rhapsody No. 1  | 1527     | John Dowland
#  | Händelgesellschaft v | Allor ch'io dissi addio ( | 1818     | Bernardo Pasqui
#  | Impromptu Op.51      | Frédéric Chopin's Impromp | 1662     | Gibbs, Joseph
#  | Impromptu, Op. 29    | Frédéric Chopin's Impromp | 1376     | Bull, John
#  | Impromptu, Op. 36    | Frédéric Chopin's Impromp | 2014     | Estevao de Brit
#  | In Nature's Realm    | The concert overture In N | 1775     | Neander, Joachi
#  | In the Steppes of Ce | In the Steppes of Central | 1716     | Emanuele d'Asto
#  | Jeux d'enfants       | Jeux d'enfants ("Children | 1867     | Barbara of Port
#  | Komm, Jesu, komm!    | Komm, Jesu, komm (Come, J | 1616     | Duarte Lobo
#  | L'Art de varier      | L'Art de varier ("The Art | 1511     | John Dowland
#  | La Savane            | La Savane (The Savannah), | 1454     | Benda, Franz
#  | Le Mancenillier      | Le Mancenillier, Op. 11,  | 1576     | Gregorio Allegr
#  | Legends, Op.59       | Legends, Op.59, B.122, (C | 1595     | Duarte Lôbo
#  | Les cinq doigts      | Les cinq doigts is a 1921 | 2009     | Peri, Jacopo
#  | Liturgy of St. John  | Liturgy of St John Chryso | 1607     | Manuel Rodrigue
#  | Lobet den Herrn, all | Lobet den Herrn, alle Hei | 1860     | Jan Pieterszoon
#  | Marie-Magdeleine     | Marie-Magdeleine is an or | 1595     | Heinrich Scheid
#  | Mass in C major      | Ludwig van Beethoven wrot | 1761     | Manuel Correia
#  | Mazurkas, Op. 30     | The Op. 30 mazurkas, by F | 1366     | Bach, Johann Mi
#  | Mazurkas, Op. 50     | The Op. 50 mazurkas by Fr | 1737     | Haym, Nicola Fr
#  | Mazurkas, Op. 56     | The Op. 56 mazurkas by Fr | 1534     | Robert Cambert
#  | Mazurkas, Op. 63     | The Op. 63 mazurkas by Fr | 1368     | Bach, Johann Mi
#  | Mazurkas, Op. 67     | The Op. 67 mazurkas by Fr | 1428     | Estevao de Brit
#  | Mazurkas, Op. 68     | The Op. 68 mazurkas by Fr | 1459     | Mattheson, Joha
#  | Moments musicaux     | Six moments musicaux, D 7 | 1867     | Giovanni Battis
#  | Morceau de salon     | Étude de perfectionnement | 1482     | Lully, Jean-Bap
#  | Morceaux de Salon, O | Morceaux de salon (French | 1536     | Samuel Scheidt
#  | Nocturne in A-flat   | Alexander Scriabin's Noct | 1594     | Gibbons, Orland
#  | Nocturne in C minor  | The Nocturne in C minor,  | 1667     | Nicolas Siret
#  | Nocturnes Op. Posth. | Nocturne in E minor, Op.  | 1913     | Gibbons, Orland
#  | Othello              | The concert overture Othe | 1572     | Robert Cambert
#  | Overture, Scherzo an | The Overture, Scherzo and | 1895     | Johann Krieger
#  | Paganini Variations, | Variations on a Theme of  | 1715     | Bononcini, Giov
#  | Papillons            | Papillons, Op. 2, is a su | 1935     | Giovanni Battis
#  | Peer Gynt Suite Suit | Morning Mood (Norwegian:  | 1972     | Giovanni Legren
#  | Polonaise Op. 44     | The Polonaise in F-sharp  | 1713     | Gibbs, Joseph
#  | Polonaise-Fantasie   | The Polonaise-fantaisie i | 1694     | Benda, Franz
#  | Polonaises Op.71     | The three Polonaises, Op. | 1672     | Caldara, Antoni
#  | Polonaises, Op.26    | The Polonaise in C-sharp  | 1565     | Cristofaro Care
#  | Polonaises, Op.40    | The twin Op. 40 Polonaise | 2011     | Hasse, Johann A
#  | Preludes Op. 11      | Alexander Scriabin's Prel | 1883     | Michael Praetor
#  | Preludes Op. 11      | Alexander Scriabin's Prel | 1719     | Caldara, Antoni
#  | Preludes Op. 11      | Alexander Scriabin's Prel | 1571     | Pierre Beaucham
#  | Preludes Op. 11 No.  | Alexander Scriabin's Prel | 1462     | Balbastre, Clau
#  | Preludes Op. 49      | Alexander Scriabin's Prel | 1712     | David Perez
#  | Preludes Op. 59      | The Prelude Op. 59 No. 2  | 1879     | John IV
#  | Preludes Op. 74      | Alexander Scriabin's Prel | 1307     | Jan Pieterszoon
#  | Preludes Opus 51     | Alexander Scriabin's Prel | 2007     | Bach, Wilhelm F
#  | Preludes, Op. 32     | Thirteen Preludes (Russia | 1624     | Reincken, Johan
#  | Première rhapsodie   | The Première rhapsodie (F | 1373     | John IV
#  | Prince Rostislav     | Prince Rostislav is a sym | 1729     | Benda, Franz
#  | Präludium und Fuge ü | Fantasie und Fuge über da | 1858     | Peter Philips
#  | Prélude, Choral et F | Prélude, Choral et Fugue, | 1442     | Jean-Marie Lecl
#  | Psalm 42 , Op. 42    | Psalm 42 op. 42 (MWV A 15 | 1857     | Cavalli, France
#  | Rhapsodie Espagnole  | Rhapsodie espagnole (Span | 1301     | Neander, Joachi
#  | Rhapsodies, Op. 79   | The Rhapsodies, Op. 79, f | 2009     | Stefano Landi
#  | Romance in F major   | The Romance for Violin an | 1323     | John Blow
#  | Romance in G major   | The Romance for Violin an | 1538     | Monteverdi, Cla
#  | Rondo Op. 1          | The Rondo in C minor, Op. | 1588     | Lôbo, Duarte
#  | Rondo Op. 5          | The Rondo à la mazur in F | 1691     | Rameau, Jean-Ph
#  | Rondo for Piano No.  | Rondo in A minor, K. 511, | 1435     | Titelouze, Jean
#  | Salve Regina         | Salve Regina, S. 66, is a | 1861     | Friederike Soph
#  | Scans of the Bach Ge | The Eight Short Preludes  | 1571     | Cabanilles, Jua
#  | Scherzo No. 2        | The Scherzo No. 2 in B-fl | 1851     | Domenico Scarla
#  | Scherzo No.3         | The Scherzo No. 3, Op. 39 | 1780     | Schenck, Johann
#  | Scherzo No.4         | Frédéric Chopin composed  | 1527     | Bach, Johann Ch
#  | Schubert's Valses No | Franz Schubert wrote abou | 1549     | Madre De Deus,
#  | Serenade for Strings | Tchaikovsky's Serenade fo | 1458     | Manuel Cardoso
#  | Serenade for Strings | The Serenade for Strings  | 1900     | Pedro de Araujo
#  | Serenade for Strings | The Serenade for Strings  | 1814     | Biber, Heinrich
#  | Serenade for Wind In | Serenade for wind instrum | 1454     | Tomaso Albinoni
#  | Serenata Notturna    | The Serenade for Orchestr | 1768     | Johann Joachim
#  | Shéhérazade          | Shéhérazade is the title  | 1517     | Antonio Maria A
#  | Shéhérazade, ouvertu | Shéhérazade is the title  | 1726     | Barbara of Port
#  | Sigurd Jorsalfar     | Sigurd Jorsalfar is an or | 1931     | Johann Joachim
#  | Singet dem Herrn ein | Singet dem Herrn ein neue | 1930     | Paolo Agostino
#  | Six Pieces for Piano | The Six Pieces for Piano, | 1589     | Manuel Correia
#  | Sonatas and Partitas | The Partita No. 3 in E ma | 1938     | Giuseppe Tartin
#  | Sonatina in F major  | The Sonatina in F is a co | 1921     | Balbastre, Clau
#  | Sonatina in G        | Sonatina in G major (Anh. | 1913     | Monsieur de Sai
#  | Sonnerie de Ste-Gene | Sonnerie de Sainte-Genevi | 2012     | Krebs, Johann L
#  | St. Paul's Suite     | St Paul's Suite (Op. 29,  | 1635     | Cabanilles, Jua
#  | Stabat Mater         | Stabat Mater for solo alt | 1756     | Pergolesi, Giov
#  | Suite No. 1 for two  | Suite No. 1 (or Fantaisie | 1439     | Alessandro Stra
#  | Suite No. 2 for two  | Suite No. 2, Op. 17, is a | 1477     | Friederike Soph
#  | Suite for Orchestra  | Kalinnikov's Suite for Or | 1758     | Handel, George
#  | Suite in D minor, HW | The Keyboard suite in D m | 1432     | Martini, Giovan
#  | Symphonic Dances, Op | The four Symphonic Dances | 1501     | John Dowland
#  | Symphonic Poem No.1, | Ce qu'on entend sur la mo | 1997     | Boyvin, Jacques
#  | Symphonies de Beetho | Beethoven Symphonies (Fre | 1720     | Jean-Joseph Mou
#  | Syrinx               | Syrinx, L. 129, is a piec | 1893     | Elisabeth Sophi
#  | Tapiola              | Tapiola (literally, "Real | 1417     | John Blow
#  | The Creatures of Pro | The Creatures of Promethe | 1565     | Viadana, Lodovi
#  | The Noon Witch       | The Noon Witch (or The No | 1449     | John IV
#  | The Storm, Op.76     | The Storm, Op. posth. 76, | 1968     | Manuel Correia
#  | Tragic Overture      | The Tragic Overture (Germ | 1330     | Peter Philips
#  | Transcendental Étude | Transcendental Étude No.  | 1676     | John Eccles
#  | Transcendental Étude | Franz Liszt's Transcenden | 1501     | Viadana, Lodovi
#  | Transcendental Étude | Transcendental Étude No.  | 1489     | Hans Leo Haßler
#  | Transcendental Étude | Transcendental Étude No.  | 1561     | Robert Cambert
#  | Tönet, ihr Pauken! E | Tönet, ihr Pauken! Erscha | 1300     | Durante, France
#  | Valse romantique     | Valse romantique is a sol | 1643     | Titelouze, Jean
#  | Valses Sentimentales | Franz Schubert wrote abou | 1313     | Fernandes, Gasp
#  | Variation on a Waltz | Variation on a Waltz by D | 1517     | Stefano Landi
#  | Variations in F mino | The Andante with variatio | 1353     | Louis Couperin
#  | Variations on a Them | Not to be confused with w | 1944     | Jeremiah Clarke
#  | Variations on a Them | Variations on a Theme of  | 1431     | Johann Ernst Eb
#  | Vers la flamme       | Vers la flamme ("Toward t | 1642     | Paolo Agostino
#  | Waltzes, Op. 34      | The three Waltzes, Op. 34 | 1867     | Giovanni Gabrie
#  | Wedding day at Trold | "Wedding Day at Troldhaug | 1337     | Johann Ernst Eb
#  | Études Op. 25        | Étude Op. 25, No. 2, in F | 1540     | Filipe De Magal
#  | Études Op. 25        | Étude Op. 25, No. 6, in G | 1863     | Weldon, John
#  | Études Op. 25        | Étude Op. 25, No. 3, in F | 1673     | Georg Muffat
#  | Études Op. 25        | Étude Op. 25, No. 4 in A  | 1996     | Reincken, Johan
#  | Études Op. 25        | Étude Op. 25, No. 8, in D | 2002     | Jean-Joseph Mou
#  | Études Op.10         | Étude Op. 10, No. 11, in  | 1851     | Martini, Giovan
#  | Études Op.10         | Étude Op. 10, No. 9, in F | 1739     | Nicolaus Bruhns

# %%
aula6_2.imprime1(obras)
# Out:
# [('Ab Irato', '1749'),
#  ('Adagio in B minor', '1418'),
#  ('Bagatelles, Opus 119', '1589'),
#  ('Bagatelles, Opus 33', '1551'),
#  ('Ballade No.1', '1370'),
#  ('Ballades, Op. 10', '1481'),
#  ('Bamboula, Op. 2', '1763'),
#  ('Barcarole Op. 60', '1423'),
#  ('Berceuse', '1972'),
#  ('Book II', '1855'),
#  ('Cantatas, BWV 141-150', '1634'),
#  ('Capriccio Italien', '1795'),
#  ('Carnival Overture', '1563'),
#  ('Coriolan Overture', '1452'),
#  ('Czech Suite', '1796'),
#  ('Die Ideale, S.106', '1663'),
#  ('Dixit Dominus', '1453'),
#  ('Eleven Chorale Preludes, Op. 122', '1961'),
#  ('Eroica Variations', '1431'),
#  ('Estampes', '1598'),
#  ('Fantaisie brillante, Op. 22', '1551'),
#  ('Fantasia and Fugue, BWV 542, G minor', '1341'),
#  ('Fantasia in D minor', '1442'),
#  ('Fantasy No. 2', '1683'),
#  ('Fantasy No. 4', '1864'),
#  ('Fantasy on Hungarian Folk Themes', '1495'),
#  ('Faust Overture', '1412'),
#  ('Festklänge, S.101', '1640'),
#  ("Feu d'artifice", '1869'),
#  ("Feuilles d'Album", '1857'),
#  ('French Overture', '1810'),
#  ('Funeral March in Memory of Rikard Nordraak', '1602'),
#  ('Fürchte dich nicht', '1975'),
#  ('Gigue in G major, K. 574', '1383'),
#  ('Grande Tarantelle', '1854'),
#  ('Grande valse brillante', '1330'),
#  ('Hamlet, S.104', '1565'),
#  ('Hungarian Rhapsody No. 10', '1602'),
#  ('Hungarian Rhapsody No. 11', '1454'),
#  ('Hungarian Rhapsody No. 12', '1522'),
#  ('Hungarian Rhapsody No. 13', '1442'),
#  ('Hungarian Rhapsody No. 14', '1788'),
#  ('Hungarian Rhapsody No. 15', '1302'),
#  ('Hungarian Rhapsody No. 16', '1706'),
#  ('Hungarian Rhapsody No. 17', '1940'),
#  ('Hungarian Rhapsody No. 18', '1798'),
#  ('Hungarian Rhapsody No. 3', '1354'),
#  ('Hungarian Rhapsody No. 4', '1377'),
#  ('Hungarian Rhapsody No. 5', '1743'),
#  ('Hungarian Rhapsody No. 7', '1485'),
#  ('Hungarian Rhapsody No. 8', '1676'),
#  ('Hungarian Rhapsody No. 9', '1994'),
#  ('Hungarian Rhapsody No.1', '1527'),
#  ('Händelgesellschaft volume 50', '1818'),
#  ('Impromptu Op.51', '1662'),
#  ('Impromptu, Op. 29', '1376'),
#  ('Impromptu, Op. 36', '2014'),
#  ("In Nature's Realm", '1775'),
#  ('In the Steppes of Central Asia', '1716'),
#  ("Jeux d'enfants", '1867'),
#  ('Komm, Jesu, komm!', '1616'),
#  ("L'Art de varier", '1511'),
#  ('La Savane', '1454'),
#  ('Le Mancenillier', '1576'),
#  ('Legends, Op.59', '1595'),
#  ('Les cinq doigts', '2009'),
#  ('Liturgy of St. John Chrysostom', '1607'),
#  ('Lobet den Herrn, alle Heiden', '1860'),
#  ('Marie-Magdeleine', '1595'),
#  ('Mass in C major', '1761'),
#  ('Mazurkas, Op. 30', '1366'),
#  ('Mazurkas, Op. 50', '1737'),
#  ('Mazurkas, Op. 56', '1534'),
#  ('Mazurkas, Op. 63', '1368'),
#  ('Mazurkas, Op. 67', '1428'),
#  ('Mazurkas, Op. 68', '1459'),
#  ('Military Band No. 1', '1673'),
#  ('Moments musicaux', '1867'),
#  ('Morceau de salon', '1482'),
#  ('Morceaux de Salon, Op. 10', '1536'),
#  ('Nocturne in A-flat', '1594'),
#  ('Nocturne in C minor', '1667'),
#  ('Nocturnes Op. Posth. 72', '1913'),
#  ('Othello', '1572'),
#  ('Overture, Scherzo and Finale', '1895'),
#  ('Paganini Variations, Book I', '1715'),
#  ('Papillons', '1935'),
#  ('Peer Gynt Suite Suite No. 1', '1972'),
#  ('Polonaise Op. 44', '1713'),
#  ('Polonaise-Fantasie', '1694'),
#  ('Polonaises Op.71', '1672'),
#  ('Polonaises, Op.26', '1565'),
#  ('Polonaises, Op.40', '2011'),
#  ('Preludes Op. 11', '1883'),
#  ('Preludes Op. 11', '1719'),
#  ('Preludes Op. 11', '1571'),
#  ('Preludes Op. 11 No. 4', '1462'),
#  ('Preludes Op. 49', '1712'),
#  ('Preludes Op. 59', '1879'),
#  ('Preludes Op. 74', '1307'),
#  ('Preludes Opus 51', '2007'),
#  ('Preludes, Op. 32', '1624'),
#  ('Première rhapsodie', '1373'),
#  ('Prince Rostislav', '1729'),
#  ('Präludium und Fuge über das Thema B-A-C-H', '1858'),
#  ('Prélude, Choral et Fugue', '1442'),
#  ('Psalm 42 , Op. 42', '1857'),
#  ('Rage Over a Lost Penny', '1745'),
#  ('Rhapsodie Espagnole', '1301'),
#  ('Rhapsodies, Op. 79', '2009'),
#  ('Romance in F major', '1323'),
#  ('Romance in G major', '1538'),
#  ('Rondo Op. 1', '1588'),
#  ('Rondo Op. 5', '1691'),
#  ('Rondo for Piano No. 3', '1435'),
#  ('Salve Regina', '1861'),
#  ('Scans of the Bach Gesellschaft edition of the Eight Short Preludes and Fugues',
#   '1571'),
#  ('Scherzo No. 2', '1851'),
#  ('Scherzo No.3', '1780'),
#  ('Scherzo No.4', '1527'),
#  ("Schubert's Valses Nobles", '1549'),
#  ('Serenade for Strings', '1458'),
#  ('Serenade for Strings', '1900'),
#  ('Serenade for Strings in G minor', '1814'),
#  ('Serenade for Wind Instruments', '1454'),
#  ('Serenata Notturna', '1768'),
#  ('Shéhérazade', '1517'),
#  ('Shéhérazade, ouverture de féerie', '1726'),
#  ('Sigurd Jorsalfar', '1931'),
#  ('Singet dem Herrn ein neues Lied', '1930'),
#  ('Six Pieces for Piano, Op. 118', '1589'),
#  ('Sonatas and Partitas for Solo Violin', '1938'),
#  ('Sonatina in F major', '1921'),
#  ('Sonatina in G', '1913'),
#  ('Sonnerie de Ste-Geneviève du Mont-de-Paris', '2012'),
#  ("St. Paul's Suite", '1635'),
#  ('Stabat Mater', '1756'),
#  ('Suite No. 1 for two pianos', '1439'),
#  ('Suite No. 2 for two pianos', '1477'),
#  ('Suite for Orchestra in B minor', '1758'),
#  ('Suite in D minor, HWV 437', '1432'),
#  ('Symphonic Dances, Op. 64', '1501'),
#  ("Symphonic Poem No.1, Ce qu'on entend sur la montagne", '1997'),
#  ('Symphonies de Beethoven', '1720'),
#  ('Syrinx', '1893'),
#  ('Tapiola', '1417'),
#  ('The Creatures of Prometheus', '1565'),
#  ('The Noon Witch', '1449'),
#  ('The Rondo', '1744'),
#  ('The Storm, Op.76', '1968'),
#  ('Three Pieces for Orchestra', '1470'),
#  ('Tragic Overture', '1330'),
#  ('Transcendental Études', '1676'),
#  ('Transcendental Études', '1501'),
#  ('Transcendental Études', '1489'),
#  ('Transcendental Études', '1561'),
#  ('Tönet, ihr Pauken! Erschallet, Trompeten!, BWV 214', '1300'),
#  ('Valse romantique', '1643'),
#  ('Valses Sentimentales', '1313'),
#  ('Variation on a Waltz by Diabelli', '1517'),
#  ('Variations in F minor', '1353'),
#  ('Variations on a Theme of Chopin, Op. 22', '1944'),
#  ('Variations on a Theme of Corelli, Op. 42', '1431'),
#  ('Vers la flamme', '1642'),
#  ('Waltzes, Op. 34', '1867'),
#  ('Wedding day at Troldhaugen', '1337'),
#  ('Zärtliche Liebe', '1791'),
#  ('Études Op. 25', '1540'),
#  ('Études Op. 25', '1863'),
#  ('Études Op. 25', '1673'),
#  ('Études Op. 25', '1996'),
#  ('Études Op. 25', '2002'),
#  ('Études Op.10', '1851'),
#  ('Études Op.10', '1739')]

# %%
aula6_2.imprime2(obras)
# Out:
# [('Tönet, ihr Pauken! Erschallet, Trompeten!, BWV 214', '1300'),
#  ('Rhapsodie Espagnole', '1301'),
#  ('Hungarian Rhapsody No. 15', '1302'),
#  ('Preludes Op. 74', '1307'),
#  ('Valses Sentimentales', '1313'),
#  ('Romance in F major', '1323'),
#  ('Grande valse brillante', '1330'),
#  ('Tragic Overture', '1330'),
#  ('Wedding day at Troldhaugen', '1337'),
#  ('Fantasia and Fugue, BWV 542, G minor', '1341'),
#  ('Variations in F minor', '1353'),
#  ('Hungarian Rhapsody No. 3', '1354'),
#  ('Mazurkas, Op. 30', '1366'),
#  ('Mazurkas, Op. 63', '1368'),
#  ('Ballade No.1', '1370'),
#  ('Première rhapsodie', '1373'),
#  ('Impromptu, Op. 29', '1376'),
#  ('Hungarian Rhapsody No. 4', '1377'),
#  ('Gigue in G major, K. 574', '1383'),
#  ('Faust Overture', '1412'),
#  ('Tapiola', '1417'),
#  ('Adagio in B minor', '1418'),
#  ('Barcarole Op. 60', '1423'),
#  ('Mazurkas, Op. 67', '1428'),
#  ('Eroica Variations', '1431'),
#  ('Variations on a Theme of Corelli, Op. 42', '1431'),
#  ('Suite in D minor, HWV 437', '1432'),
#  ('Rondo for Piano No. 3', '1435'),
#  ('Suite No. 1 for two pianos', '1439'),
#  ('Fantasia in D minor', '1442'),
#  ('Hungarian Rhapsody No. 13', '1442'),
#  ('Prélude, Choral et Fugue', '1442'),
#  ('The Noon Witch', '1449'),
#  ('Coriolan Overture', '1452'),
#  ('Dixit Dominus', '1453'),
#  ('Hungarian Rhapsody No. 11', '1454'),
#  ('La Savane', '1454'),
#  ('Serenade for Wind Instruments', '1454'),
#  ('Serenade for Strings', '1458'),
#  ('Mazurkas, Op. 68', '1459'),
#  ('Preludes Op. 11 No. 4', '1462'),
#  ('Three Pieces for Orchestra', '1470'),
#  ('Suite No. 2 for two pianos', '1477'),
#  ('Ballades, Op. 10', '1481'),
#  ('Morceau de salon', '1482'),
#  ('Hungarian Rhapsody No. 7', '1485'),
#  ('Transcendental Études', '1489'),
#  ('Fantasy on Hungarian Folk Themes', '1495'),
#  ('Symphonic Dances, Op. 64', '1501'),
#  ('Transcendental Études', '1501'),
#  ("L'Art de varier", '1511'),
#  ('Shéhérazade', '1517'),
#  ('Variation on a Waltz by Diabelli', '1517'),
#  ('Hungarian Rhapsody No. 12', '1522'),
#  ('Hungarian Rhapsody No.1', '1527'),
#  ('Scherzo No.4', '1527'),
#  ('Mazurkas, Op. 56', '1534'),
#  ('Morceaux de Salon, Op. 10', '1536'),
#  ('Romance in G major', '1538'),
#  ('Études Op. 25', '1540'),
#  ("Schubert's Valses Nobles", '1549'),
#  ('Bagatelles, Opus 33', '1551'),
#  ('Fantaisie brillante, Op. 22', '1551'),
#  ('Transcendental Études', '1561'),
#  ('Carnival Overture', '1563'),
#  ('Hamlet, S.104', '1565'),
#  ('Polonaises, Op.26', '1565'),
#  ('The Creatures of Prometheus', '1565'),
#  ('Preludes Op. 11', '1571'),
#  ('Scans of the Bach Gesellschaft edition of the Eight Short Preludes and Fugues',
#   '1571'),
#  ('Othello', '1572'),
#  ('Le Mancenillier', '1576'),
#  ('Rondo Op. 1', '1588'),
#  ('Bagatelles, Opus 119', '1589'),
#  ('Six Pieces for Piano, Op. 118', '1589'),
#  ('Nocturne in A-flat', '1594'),
#  ('Legends, Op.59', '1595'),
#  ('Marie-Magdeleine', '1595'),
#  ('Estampes', '1598'),
#  ('Funeral March in Memory of Rikard Nordraak', '1602'),
#  ('Hungarian Rhapsody No. 10', '1602'),
#  ('Liturgy of St. John Chrysostom', '1607'),
#  ('Komm, Jesu, komm!', '1616'),
#  ('Preludes, Op. 32', '1624'),
#  ('Cantatas, BWV 141-150', '1634'),
#  ("St. Paul's Suite", '1635'),
#  ('Festklänge, S.101', '1640'),
#  ('Vers la flamme', '1642'),
#  ('Valse romantique', '1643'),
#  ('Impromptu Op.51', '1662'),
#  ('Die Ideale, S.106', '1663'),
#  ('Nocturne in C minor', '1667'),
#  ('Polonaises Op.71', '1672'),
#  ('Military Band No. 1', '1673'),
#  ('Études Op. 25', '1673'),
#  ('Hungarian Rhapsody No. 8', '1676'),
#  ('Transcendental Études', '1676'),
#  ('Fantasy No. 2', '1683'),
#  ('Rondo Op. 5', '1691'),
#  ('Polonaise-Fantasie', '1694'),
#  ('Hungarian Rhapsody No. 16', '1706'),
#  ('Preludes Op. 49', '1712'),
#  ('Polonaise Op. 44', '1713'),
#  ('Paganini Variations, Book I', '1715'),
#  ('In the Steppes of Central Asia', '1716'),
#  ('Preludes Op. 11', '1719'),
#  ('Symphonies de Beethoven', '1720'),
#  ('Shéhérazade, ouverture de féerie', '1726'),
#  ('Prince Rostislav', '1729'),
#  ('Mazurkas, Op. 50', '1737'),
#  ('Études Op.10', '1739'),
#  ('Hungarian Rhapsody No. 5', '1743'),
#  ('The Rondo', '1744'),
#  ('Rage Over a Lost Penny', '1745'),
#  ('Ab Irato', '1749'),
#  ('Stabat Mater', '1756'),
#  ('Suite for Orchestra in B minor', '1758'),
#  ('Mass in C major', '1761'),
#  ('Bamboula, Op. 2', '1763'),
#  ('Serenata Notturna', '1768'),
#  ("In Nature's Realm", '1775'),
#  ('Scherzo No.3', '1780'),
#  ('Hungarian Rhapsody No. 14', '1788'),
#  ('Zärtliche Liebe', '1791'),
#  ('Capriccio Italien', '1795'),
#  ('Czech Suite', '1796'),
#  ('Hungarian Rhapsody No. 18', '1798'),
#  ('French Overture', '1810'),
#  ('Serenade for Strings in G minor', '1814'),
#  ('Händelgesellschaft volume 50', '1818'),
#  ('Scherzo No. 2', '1851'),
#  ('Études Op.10', '1851'),
#  ('Grande Tarantelle', '1854'),
#  ('Book II', '1855'),
#  ("Feuilles d'Album", '1857'),
#  ('Psalm 42 , Op. 42', '1857'),
#  ('Präludium und Fuge über das Thema B-A-C-H', '1858'),
#  ('Lobet den Herrn, alle Heiden', '1860'),
#  ('Salve Regina', '1861'),
#  ('Études Op. 25', '1863'),
#  ('Fantasy No. 4', '1864'),
#  ("Jeux d'enfants", '1867'),
#  ('Moments musicaux', '1867'),
#  ('Waltzes, Op. 34', '1867'),
#  ("Feu d'artifice", '1869'),
#  ('Preludes Op. 59', '1879'),
#  ('Preludes Op. 11', '1883'),
#  ('Syrinx', '1893'),
#  ('Overture, Scherzo and Finale', '1895'),
#  ('Serenade for Strings', '1900'),
#  ('Nocturnes Op. Posth. 72', '1913'),
#  ('Sonatina in G', '1913'),
#  ('Sonatina in F major', '1921'),
#  ('Singet dem Herrn ein neues Lied', '1930'),
#  ('Sigurd Jorsalfar', '1931'),
#  ('Papillons', '1935'),
#  ('Sonatas and Partitas for Solo Violin', '1938'),
#  ('Hungarian Rhapsody No. 17', '1940'),
#  ('Variations on a Theme of Chopin, Op. 22', '1944'),
#  ('Eleven Chorale Preludes, Op. 122', '1961'),
#  ('The Storm, Op.76', '1968'),
#  ('Berceuse', '1972'),
#  ('Peer Gynt Suite Suite No. 1', '1972'),
#  ('Fürchte dich nicht', '1975'),
#  ('Hungarian Rhapsody No. 9', '1994'),
#  ('Études Op. 25', '1996'),
#  ("Symphonic Poem No.1, Ce qu'on entend sur la montagne", '1997'),
#  ('Études Op. 25', '2002'),
#  ('Preludes Opus 51', '2007'),
#  ('Les cinq doigts', '2009'),
#  ('Rhapsodies, Op. 79', '2009'),
#  ('Polonaises, Op.40', '2011'),
#  ('Sonnerie de Ste-Geneviève du Mont-de-Paris', '2012'),
#  ('Impromptu, Op. 36', '2014')]

# %%
aula6_2.titporAno(obras)
# Out:
# {'1745': ['Rage Over a Lost Penny'],
#  '1791': ['Zärtliche Liebe'],
#  '1673': ['Military Band No. 1', 'Études Op. 25'],
#  '1744': ['The Rondo'],
#  '1470': ['Three Pieces for Orchestra'],
#  '1749': ['Ab Irato'],
#  '1418': ['Adagio in B minor'],
#  '1589': ['Bagatelles, Opus 119', 'Six Pieces for Piano, Op. 118'],
#  '1551': ['Bagatelles, Opus 33', 'Fantaisie brillante, Op. 22'],
#  '1370': ['Ballade No.1'],
#  '1481': ['Ballades, Op. 10'],
#  '1763': ['Bamboula, Op. 2'],
#  '1423': ['Barcarole Op. 60'],
#  '1972': ['Berceuse', 'Peer Gynt Suite Suite No. 1'],
#  '1855': ['Book II'],
#  '1634': ['Cantatas, BWV 141-150'],
#  '1795': ['Capriccio Italien'],
#  '1563': ['Carnival Overture'],
#  '1452': ['Coriolan Overture'],
#  '1796': ['Czech Suite'],
#  '1663': ['Die Ideale, S.106'],
#  '1453': ['Dixit Dominus'],
#  '1961': ['Eleven Chorale Preludes, Op. 122'],
#  '1431': ['Eroica Variations', 'Variations on a Theme of Corelli, Op. 42'],
#  '1598': ['Estampes'],
#  '1341': ['Fantasia and Fugue, BWV 542, G minor'],
#  '1442': ['Fantasia in D minor',
#   'Hungarian Rhapsody No. 13',
#   'Prélude, Choral et Fugue'],
#  '1683': ['Fantasy No. 2'],
#  '1864': ['Fantasy No. 4'],
#  '1495': ['Fantasy on Hungarian Folk Themes'],
#  '1412': ['Faust Overture'],
#  '1640': ['Festklänge, S.101'],
#  '1869': ["Feu d'artifice"],
#  '1857': ["Feuilles d'Album", 'Psalm 42 , Op. 42'],
#  '1810': ['French Overture'],
#  '1602': ['Funeral March in Memory of Rikard Nordraak',
#   'Hungarian Rhapsody No. 10'],
#  '1975': ['Fürchte dich nicht'],
#  '1383': ['Gigue in G major, K. 574'],
#  '1854': ['Grande Tarantelle'],
#  '1330': ['Grande valse brillante', 'Tragic Overture'],
#  '1565': ['Hamlet, S.104', 'Polonaises, Op.26', 'The Creatures of Prometheus'],
#  '1454': ['Hungarian Rhapsody No. 11',
#   'La Savane',
#   'Serenade for Wind Instruments'],
#  '1522': ['Hungarian Rhapsody No. 12'],
#  '1788': ['Hungarian Rhapsody No. 14'],
#  '1302': ['Hungarian Rhapsody No. 15'],
#  '1706': ['Hungarian Rhapsody No. 16'],
#  '1940': ['Hungarian Rhapsody No. 17'],
#  '1798': ['Hungarian Rhapsody No. 18'],
#  '1354': ['Hungarian Rhapsody No. 3'],
#  '1377': ['Hungarian Rhapsody No. 4'],
#  '1743': ['Hungarian Rhapsody No. 5'],
#  '1485': ['Hungarian Rhapsody No. 7'],
#  '1676': ['Hungarian Rhapsody No. 8', 'Transcendental Études'],
#  '1994': ['Hungarian Rhapsody No. 9'],
#  '1527': ['Hungarian Rhapsody No.1', 'Scherzo No.4'],
#  '1818': ['Händelgesellschaft volume 50'],
#  '1662': ['Impromptu Op.51'],
#  '1376': ['Impromptu, Op. 29'],
#  '2014': ['Impromptu, Op. 36'],
#  '1775': ["In Nature's Realm"],
#  '1716': ['In the Steppes of Central Asia'],
#  '1867': ["Jeux d'enfants", 'Moments musicaux', 'Waltzes, Op. 34'],
#  '1616': ['Komm, Jesu, komm!'],
#  '1511': ["L'Art de varier"],
#  '1576': ['Le Mancenillier'],
#  '1595': ['Legends, Op.59', 'Marie-Magdeleine'],
#  '2009': ['Les cinq doigts', 'Rhapsodies, Op. 79'],
#  '1607': ['Liturgy of St. John Chrysostom'],
#  '1860': ['Lobet den Herrn, alle Heiden'],
#  '1761': ['Mass in C major'],
#  '1366': ['Mazurkas, Op. 30'],
#  '1737': ['Mazurkas, Op. 50'],
#  '1534': ['Mazurkas, Op. 56'],
#  '1368': ['Mazurkas, Op. 63'],
#  '1428': ['Mazurkas, Op. 67'],
#  '1459': ['Mazurkas, Op. 68'],
#  '1482': ['Morceau de salon'],
#  '1536': ['Morceaux de Salon, Op. 10'],
#  '1594': ['Nocturne in A-flat'],
#  '1667': ['Nocturne in C minor'],
#  '1913': ['Nocturnes Op. Posth. 72', 'Sonatina in G'],
#  '1572': ['Othello'],
#  '1895': ['Overture, Scherzo and Finale'],
#  '1715': ['Paganini Variations, Book I'],
#  '1935': ['Papillons'],
#  '1713': ['Polonaise Op. 44'],
#  '1694': ['Polonaise-Fantasie'],
#  '1672': ['Polonaises Op.71'],
#  '2011': ['Polonaises, Op.40'],
#  '1883': ['Preludes Op. 11'],
#  '1719': ['Preludes Op. 11'],
#  '1571': ['Preludes Op. 11',
#   'Scans of the Bach Gesellschaft edition of the Eight Short Preludes and Fugues'],
#  '1462': ['Preludes Op. 11 No. 4'],
#  '1712': ['Preludes Op. 49'],
#  '1879': ['Preludes Op. 59'],
#  '1307': ['Preludes Op. 74'],
#  '2007': ['Preludes Opus 51'],
#  '1624': ['Preludes, Op. 32'],
#  '1373': ['Première rhapsodie'],
#  '1729': ['Prince Rostislav'],
#  '1858': ['Präludium und Fuge über das Thema B-A-C-H'],
#  '1301': ['Rhapsodie Espagnole'],
#  '1323': ['Romance in F major'],
#  '1538': ['Romance in G major'],
#  '1588': ['Rondo Op. 1'],
#  '1691': ['Rondo Op. 5'],
#  '1435': ['Rondo for Piano No. 3'],
#  '1861': ['Salve Regina'],
#  '1851': ['Scherzo No. 2', 'Études Op.10'],
#  '1780': ['Scherzo No.3'],
#  '1549': ["Schubert's Valses Nobles"],
#  '1458': ['Serenade for Strings'],
#  '1900': ['Serenade for Strings'],
#  '1814': ['Serenade for Strings in G minor'],
#  '1768': ['Serenata Notturna'],
#  '1517': ['Shéhérazade', 'Variation on a Waltz by Diabelli'],
#  '1726': ['Shéhérazade, ouverture de féerie'],
#  '1931': ['Sigurd Jorsalfar'],
#  '1930': ['Singet dem Herrn ein neues Lied'],
#  '1938': ['Sonatas and Partitas for Solo Violin'],
#  '1921': ['Sonatina in F major'],
#  '2012': ['Sonnerie de Ste-Geneviève du Mont-de-Paris'],
#  '1635': ["St. Paul's Suite"],
#  '1756': ['Stabat Mater'],
#  '1439': ['Suite No. 1 for two pianos'],
#  '1477': ['Suite No. 2 for two pianos'],
#  '1758': ['Suite for Orchestra in B minor'],
#  '1432': ['Suite in D minor, HWV 437'],
#  '1501': ['Symphonic Dances, Op. 64', 'Transcendental Études'],
#  '1997': ["Symphonic Poem No.1, Ce qu'on entend sur la montagne"],
#  '1720': ['Symphonies de Beethoven'],
#  '1893': ['Syrinx'],
#  '1417': ['Tapiola'],
#  '1449': ['The Noon Witch'],
#  '1968': ['The Storm, Op.76'],
#  '1489': ['Transcendental Études'],
#  '1561': ['Transcendental Études'],
#  '1300': ['Tönet, ihr Pauken! Erschallet, Trompeten!, BWV 214'],
#  '1643': ['Valse romantique'],
#  '1313': ['Valses Sentimentales'],
#  '1353': ['Variations in F minor'],
#  '1944': ['Variations on a Theme of Chopin, Op. 22'],
#  '1642': ['Vers la flamme'],
#  '1337': ['Wedding day at Troldhaugen'],
#  '1540': ['Études Op. 25'],
#  '1863': ['Études Op. 25'],
#  '1996': ['Études Op. 25'],
#  '2002': ['Études Op. 25'],
#  '1739': ['Études Op.10']}

# %%
aula6_2.titporPeriodo(obras)
# Out:
# {'Barroco': 26,
#  'Clássico': 15,
#  'Medieval': 48,
#  'Renascimento': 41,
#  'Século XX': 18,
#  'Romântico': 19,
#  'Contemporâneo': 7}

# %%
aula6_2.titporComp(obras)
# Out:
# ['Antonio Maria Abbatini',
#  'Alessandro Stradella',
#  'Bach, Wilhelm Friedemann',
#  'Bach, Wilhelm Friedemann',
#  'Baldassare Galuppi',
#  'Bernardo Pasquini',
#  'Bull, John',
#  'Barbara of Portugal',
#  'Benda, Franz',
#  'Bach, Johann Michael',
#  'Bach, Johann Michael',
#  'Bononcini, Giovanni Battista',
#  'Benda, Franz',
#  'Balbastre, Claude',
#  'Bach, Wilhelm Friedemann',
#  'Benda, Franz',
#  'Bach, Johann Christoph',
#  'Biber, Heinrich Ignaz Franz',
#  'Barbara of Portugal',
#  'Balbastre, Claude',
#  'Boyvin, Jacques',
#  'Caldara, Antonio',
#  'Carissimi, Giacomo',
#  'Carissimi, Giacomo',
#  'Carissimi, Giacomo',
#  'Caldara, Antonio',
#  'Caldara, Antonio',
#  'Cristofaro Caresana',
#  'Caldara, Antonio',
#  'Cavalli, Francesco',
#  'Cabanilles, Juan Bautista',
#  'Cabanilles, Juan Bautista',
#  'Durante, Francesco',
#  'Dieterich Buxtehude',
#  'Duarte Lobo',
#  'Duarte Lôbo',
#  'David Perez',
#  'Domenico Scarlatti',
#  'Durante, Francesco',
#  "Emanuele d'Astorga",
#  'Estevao de Brito',
#  "Emanuele d'Astorga",
#  'Estevao de Brito',
#  'Elisabeth Sophie of Mecklenburg',
#  'Friederike Sophie Wilhelmine',
#  'Froberger, Johann Jakob',
#  'Friederike Sophie Wilhelmine',
#  'Friederike Sophie Wilhelmine',
#  'Fernandes, Gaspar',
#  'Filipe De Magalhaes',
#  'Gregor Aichinger',
#  'Giovanni Gabrieli',
#  'Gregor Aichinger',
#  'Georg Bohm',
#  'Gibbs, Joseph',
#  'Gregorio Allegri',
#  'Giovanni Battista Bassani',
#  'Gibbons, Orlando',
#  'Gibbons, Orlando',
#  'Giovanni Battista Bassani',
#  'Giovanni Legrenzi',
#  'Gibbs, Joseph',
#  'Giuseppe Tartini',
#  'Giovanni Gabrieli',
#  'Georg Muffat',
#  'Hasse, Johann Adolph',
#  'Henri Desmarets',
#  'Haym, Nicola Francesco',
#  'Heinrich Scheidemann',
#  'Haym, Nicola Francesco',
#  'Hasse, Johann Adolph',
#  'Handel, George Frideric',
#  'Hans Leo Haßler',
#  'Johann David Heinichen',
#  'Johann Nicolaus Bach',
#  'John Blow',
#  'Johann Hermann Schein',
#  'Johann Christoph(er) Pepusch',
#  'Jean-Marie Leclair',
#  'Jean-Joseph Mouret',
#  'John Dowland',
#  'John Dowland',
#  'Jan Pieterszoon Sweelinck',
#  'Johann Krieger',
#  'John IV',
#  'Jan Pieterszoon Sweelinck',
#  'John IV',
#  'Jean-Marie Leclair',
#  'John Blow',
#  'Johann Joachim Quantz',
#  'Johann Joachim Quantz',
#  'John Dowland',
#  'Jean-Joseph Mouret',
#  'John Blow',
#  'John IV',
#  'John Eccles',
#  'Jeremiah Clarke',
#  'Johann Ernst Eberlin',
#  'Johann Ernst Eberlin',
#  'Jean-Joseph Mouret',
#  'Krebs, Johann Ludwig',
#  'Krebs, Johann Ludwig',
#  'Krebs, Johann Ludwig',
#  'Leopold I',
#  'Lully, Jean-Baptiste',
#  'Lôbo, Duarte',
#  'Louis Couperin',
#  'Marc-Antoine Charpentier',
#  'Melchior Schildt',
#  'Monsieur de Sainte-Colombe',
#  'Mondonville, Jean-Joseph',
#  'Manuel Rodriguez Coelho',
#  'Marais, Marin',
#  'Manuel Correia',
#  'Machado, Manuel',
#  'Manuel Rodriguez Coelho',
#  'Manuel Correia',
#  'Mattheson, Johann',
#  'Michael Praetorius',
#  'Monteverdi, Claudio',
#  'Madre De Deus, Filpe Da',
#  'Manuel Cardoso',
#  'Manuel Correia',
#  'Monsieur de Sainte-Colombe',
#  'Martini, Giovanni Battista',
#  'Manuel Correia',
#  'Martini, Giovanni Battista',
#  'Nicolaus Bruhns',
#  'Nivers, Guillaume-Gabriel',
#  'Neander, Joachim',
#  'Neander, Joachim',
#  'Nicolas Siret',
#  'Neander, Joachim',
#  'Nicolaus Bruhns',
#  'Pergolesi, Giovanni Battista',
#  'Pedro de Araujo',
#  'Peter Philips',
#  'Pietro Della Valle',
#  'Peri, Jacopo',
#  'Pierre Beauchamp',
#  'Peter Philips',
#  'Pedro de Araujo',
#  'Paolo Agostino',
#  'Pergolesi, Giovanni Battista',
#  'Peter Philips',
#  'Paolo Agostino',
#  'Reincken, Johann Adam',
#  'Rousseau, Jean-Jacques',
#  'Rousseau, Jean-Jacques',
#  'Robert Cambert',
#  'Robert Cambert',
#  'Reincken, Johann Adam',
#  'Rameau, Jean-Philippe',
#  'Robert Cambert',
#  'Reincken, Johann Adam',
#  'Sammartini, Giovanni Battista',
#  'Samuel Scheidt',
#  'Seixas, Carlos',
#  'Sanz, Gaspar',
#  'Strozzi, Barbara',
#  'Sammartini, Giuseppe',
#  'Samuel Scheidt',
#  'Stefano Landi',
#  'Schenck, Johannes',
#  'Stefano Landi',
#  'Titelouze, Jean',
#  'Tomaso Albinoni',
#  'Titelouze, Jean',
#  'Viadana, Lodovico Grossi da',
#  'Viadana, Lodovico Grossi da',
#  'Weldon, John',
#  'Weldon, John',
#  'Wilhelmine of Prussia',
#  'Weldon, John']

# %%
aula6_2.titporAnod(obras)
# Out:
# {'1745': 1,
#  '1791': 1,
#  '1673': 2,
#  '1744': 1,
#  '1470': 1,
#  '1749': 1,
#  '1418': 1,
#  '1589': 2,
#  '1551': 2,
#  '1370': 1,
#  '1481': 1,
#  '1763': 1,
#  '1423': 1,
#  '1972': 2,
#  '1855': 1,
#  '1634': 1,
#  '1795': 1,
#  '1563': 1,
#  '1452': 1,
#  '1796': 1,
#  '1663': 1,
#  '1453': 1,
#  '1961': 1,
#  '1431': 2,
#  '1598': 1,
#  '1341': 1,
#  '1442': 3,
#  '1683': 1,
#  '1864': 1,
#  '1495': 1,
#  '1412': 1,
#  '1640': 1,
#  '1869': 1,
#  '1857': 2,
#  '1810': 1,
#  '1602': 2,
#  '1975': 1,
#  '1383': 1,
#  '1854': 1,
#  '1330': 2,
#  '1565': 3,
#  '1454': 3,
#  '1522': 1,
#  '1788': 1,
#  '1302': 1,
#  '1706': 1,
#  '1940': 1,
#  '1798': 1,
#  '1354': 1,
#  '1377': 1,
#  '1743': 1,
#  '1485': 1,
#  '1676': 2,
#  '1994': 1,
#  '1527': 2,
#  '1818': 1,
#  '1662': 1,
#  '1376': 1,
#  '2014': 1,
#  '1775': 1,
#  '1716': 1,
#  '1867': 3,
#  '1616': 1,
#  '1511': 1,
#  '1576': 1,
#  '1595': 2,
#  '2009': 2,
#  '1607': 1,
#  '1860': 1,
#  '1761': 1,
#  '1366': 1,
#  '1737': 1,
#  '1534': 1,
#  '1368': 1,
#  '1428': 1,
#  '1459': 1,
#  '1482': 1,
#  '1536': 1,
#  '1594': 1,
#  '1667': 1,
#  '1913': 2,
#  '1572': 1,
#  '1895': 1,
#  '1715': 1,
#  '1935': 1,
#  '1713': 1,
#  '1694': 1,
#  '1672': 1,
#  '2011': 1,
#  '1883': 1,
#  '1719': 1,
#  '1571': 2,
#  '1462': 1,
#  '1712': 1,
#  '1879': 1,
#  '1307': 1,
#  '2007': 1,
#  '1624': 1,
#  '1373': 1,
#  '1729': 1,
#  '1858': 1,
#  '1301': 1,
#  '1323': 1,
#  '1538': 1,
#  '1588': 1,
#  '1691': 1,
#  '1435': 1,
#  '1861': 1,
#  '1851': 2,
#  '1780': 1,
#  '1549': 1,
#  '1458': 1,
#  '1900': 1,
#  '1814': 1,
#  '1768': 1,
#  '1517': 2,
#  '1726': 1,
#  '1931': 1,
#  '1930': 1,
#  '1938': 1,
#  '1921': 1,
#  '2012': 1,
#  '1635': 1,
#  '1756': 1,
#  '1439': 1,
#  '1477': 1,
#  '1758': 1,
#  '1432': 1,
#  '1501': 2,
#  '1997': 1,
#  '1720': 1,
#  '1893': 1,
#  '1417': 1,
#  '1449': 1,
#  '1968': 1,
#  '1489': 1,
#  '1561': 1,
#  '1300': 1,
#  '1643': 1,
#  '1313': 1,
#  '1353': 1,
#  '1944': 1,
#  '1642': 1,
#  '1337': 1,
#  '1540': 1,
#  '1863': 1,
#  '1996': 1,
#  '2002': 1,
#  '1739': 1}

# %%
aula6_2.titporComp1(obras)
# Out:
# {'Krebs, Johann Ludwig': 3,
#  'Reincken, Johann Adam': 3,
#  "Emanuele d'Astorga": 2,
#  'Sammartini, Giovanni Battista': 1,
#  'Nicolaus Bruhns': 2,
#  'Johann David Heinichen': 1,
#  'Durante, Francesco': 2,
#  'Gregor Aichinger': 2,
#  'Samuel Scheidt': 2,
#  'Marc-Antoine Charpentier': 1,
#  'Seixas, Carlos': 1,
#  'Hasse, Johann Adolph': 2,
#  'Melchior Schildt': 1,
#  'Johann Nicolaus Bach': 1,
#  'Monsieur de Sainte-Colombe': 2,
#  'Sanz, Gaspar': 1,
#  'Weldon, John': 3,
#  'Nivers, Guillaume-Gabriel': 1,
#  'Bach, Wilhelm Friedemann': 3,
#  'Rousseau, Jean-Jacques': 2,
#  'Mondonville, Jean-Joseph': 1,
#  'Caldara, Antonio': 4,
#  'Pergolesi, Giovanni Battista': 2,
#  'Henri Desmarets': 1,
#  'Manuel Rodriguez Coelho': 2,
#  'Giovanni Gabrieli': 2,
#  'Strozzi, Barbara': 1,
#  'Marais, Marin': 1,
#  'Sammartini, Giuseppe': 1,
#  'John Blow': 3,
#  'Carissimi, Giacomo': 3,
#  'Friederike Sophie Wilhelmine': 3,
#  'Manuel Correia': 4,
#  'Pedro de Araujo': 2,
#  'Johann Hermann Schein': 1,
#  'Leopold I': 1,
#  'Johann Christoph(er) Pepusch': 1,
#  'Machado, Manuel': 1,
#  'Peter Philips': 3,
#  'Froberger, Johann Jakob': 1,
#  'Jean-Marie Leclair': 2,
#  'Pietro Della Valle': 1,
#  'Dieterich Buxtehude': 1,
#  'Neander, Joachim': 3,
#  'Jean-Joseph Mouret': 3,
#  'Georg Bohm': 1,
#  'Baldassare Galuppi': 1,
#  'Haym, Nicola Francesco': 2,
#  'Wilhelmine of Prussia': 1,
#  'John Dowland': 3,
#  'Bernardo Pasquini': 1,
#  'Gibbs, Joseph': 2,
#  'Bull, John': 1,
#  'Estevao de Brito': 2,
#  'Barbara of Portugal': 2,
#  'Duarte Lobo': 1,
#  'Benda, Franz': 3,
#  'Gregorio Allegri': 1,
#  'Duarte Lôbo': 1,
#  'Peri, Jacopo': 1,
#  'Jan Pieterszoon Sweelinck': 2,
#  'Heinrich Scheidemann': 1,
#  'Bach, Johann Michael': 2,
#  'Robert Cambert': 3,
#  'Mattheson, Johann': 1,
#  'Giovanni Battista Bassani': 2,
#  'Lully, Jean-Baptiste': 1,
#  'Gibbons, Orlando': 2,
#  'Nicolas Siret': 1,
#  'Johann Krieger': 1,
#  'Bononcini, Giovanni Battista': 1,
#  'Giovanni Legrenzi': 1,
#  'Cristofaro Caresana': 1,
#  'Michael Praetorius': 1,
#  'Pierre Beauchamp': 1,
#  'Balbastre, Claude': 2,
#  'David Perez': 1,
#  'John IV': 3,
#  'Cavalli, Francesco': 1,
#  'Stefano Landi': 2,
#  'Monteverdi, Claudio': 1,
#  'Lôbo, Duarte': 1,
#  'Rameau, Jean-Philippe': 1,
#  'Titelouze, Jean': 2,
#  'Cabanilles, Juan Bautista': 2,
#  'Domenico Scarlatti': 1,
#  'Schenck, Johannes': 1,
#  'Bach, Johann Christoph': 1,
#  'Madre De Deus, Filpe Da': 1,
#  'Manuel Cardoso': 1,
#  'Biber, Heinrich Ignaz Franz': 1,
#  'Tomaso Albinoni': 1,
#  'Johann Joachim Quantz': 2,
#  'Antonio Maria Abbatini': 1,
#  'Paolo Agostino': 2,
#  'Giuseppe Tartini': 1,
#  'Alessandro Stradella': 1,
#  'Handel, George Frideric': 1,
#  'Martini, Giovanni Battista': 2,
#  'Boyvin, Jacques': 1,
#  'Elisabeth Sophie of Mecklenburg': 1,
#  'Viadana, Lodovico Grossi da': 2,
#  'John Eccles': 1,
#  'Hans Leo Haßler': 1,
#  'Fernandes, Gaspar': 1,
#  'Louis Couperin': 1,
#  'Jeremiah Clarke': 1,
#  'Johann Ernst Eberlin': 2,
#  'Filipe De Magalhaes': 1,
#  'Georg Muffat': 1}

# %%
aula6_2.plotDistrib(obras)

# %%
aula6_2.indComp(obras)
# Out:
# [{'compositor': 'Nicolaus Bruhns',
#   'obra': ['Three Pieces for Orchestra',
#    'Berceuse',
#    'Carnival Overture',
#    'Hungarian Rhapsody No. 16',
#    'Hungarian Rhapsody No. 8',
#    "In Nature's Realm",
#    'Mazurkas, Op. 50',
#    'Nocturne in C minor',
#    'Rhapsodie Espagnole',
#    'Études Op.10']},
#  {'compositor': 'Nicolaus Bruhns',
#   'obra': ['Rage Over a Lost Penny',
#    'Zärtliche Liebe',
#    'The Rondo',
#    'Three Pieces for Orchestra',
#    'Ab Irato',
#    'Bagatelles, Opus 119',
#    'Bagatelles, Opus 33',
#    'Ballade No.1',
#    'Ballades, Op. 10',
#    'Barcarole Op. 60',
#    'Berceuse',
#    'Book II',
#    'Carnival Overture',
#    'Coriolan Overture',
#    'Die Ideale, S.106',
#    'Dixit Dominus',
#    'Eleven Chorale Preludes, Op. 122',
#    'Eroica Variations',
#    'Estampes',
#    'Fantaisie brillante, Op. 22',
#    'Fantasia and Fugue, BWV 542, G minor',
#    'Fantasia in D minor',
#    'Fantasy No. 2',
#    'Fantasy on Hungarian Folk Themes',
#    'Faust Overture',
#    'Festklänge, S.101',
#    "Feu d'artifice",
#    "Feuilles d'Album",
#    'Funeral March in Memory of Rikard Nordraak',
#    'Fürchte dich nicht',
#    'Grande Tarantelle',
#    'Hamlet, S.104',
#    'Hungarian Rhapsody No. 10',
#    'Hungarian Rhapsody No. 13',
#    'Hungarian Rhapsody No. 14',
#    'Hungarian Rhapsody No. 15',
#    'Hungarian Rhapsody No. 16',
#    'Hungarian Rhapsody No. 3',
#    'Hungarian Rhapsody No. 5',
#    'Hungarian Rhapsody No. 7',
#    'Hungarian Rhapsody No. 8',
#    'Hungarian Rhapsody No. 9',
#    'Händelgesellschaft volume 50',
#    'Impromptu Op.51',
#    'Impromptu, Op. 36',
#    "In Nature's Realm",
#    'Le Mancenillier',
#    'Les cinq doigts',
#    'Liturgy of St. John Chrysostom',
#    'Lobet den Herrn, alle Heiden',
#    'Marie-Magdeleine',
#    'Mass in C major',
#    'Mazurkas, Op. 30',
#    'Mazurkas, Op. 50',
#    'Mazurkas, Op. 63',
#    'Mazurkas, Op. 67',
#    'Moments musicaux',
#    'Morceau de salon',
#    'Morceaux de Salon, Op. 10',
#    'Nocturne in A-flat',
#    'Nocturne in C minor',
#    'Nocturnes Op. Posth. 72',
#    'Overture, Scherzo and Finale',
#    'Paganini Variations, Book I',
#    'Papillons',
#    'Peer Gynt Suite Suite No. 1',
#    'Polonaise Op. 44',
#    'Polonaises Op.71',
#    'Polonaises, Op.26',
#    'Preludes Op. 11',
#    'Preludes Op. 11',
#    'Preludes Op. 11',
#    'Preludes Op. 49',
#    'Preludes Op. 74',
#    'Preludes Opus 51',
#    'Preludes, Op. 32',
#    'Präludium und Fuge über das Thema B-A-C-H',
#    'Prélude, Choral et Fugue',
#    'Psalm 42 , Op. 42',
#    'Rhapsodie Espagnole',
#    'Rhapsodies, Op. 79',
#    'Romance in G major',
#    'Rondo Op. 5',
#    'Rondo for Piano No. 3',
#    'Salve Regina',
#    'Scans of the Bach Gesellschaft edition of the Eight Short Preludes and Fugues',
#    'Scherzo No. 2',
#    'Scherzo No.4',
#    "Schubert's Valses Nobles",
#    'Serenade for Strings in G minor',
#    'Serenade for Wind Instruments',
#    'Serenata Notturna',
#    'Shéhérazade',
#    'Sigurd Jorsalfar',
#    'Singet dem Herrn ein neues Lied',
#    'Six Pieces for Piano, Op. 118',
#    'Sonatas and Partitas for Solo Violin',
#    'Sonatina in G',
#    'Sonnerie de Ste-Geneviève du Mont-de-Paris',
#    "St. Paul's Suite",
#    'Stabat Mater',
#    'Suite No. 2 for two pianos',
#    'Suite for Orchestra in B minor',
#    'Suite in D minor, HWV 437',
#    "Symphonic Poem No.1, Ce qu'on entend sur la montagne",
#    'Syrinx',
#    'The Creatures of Prometheus',
#    'The Storm, Op.76',
#    'Tragic Overture',
#    'Transcendental Études',
#    'Valse romantique',
#    'Variation on a Waltz by Diabelli',
#    'Variations in F minor',
#    'Variations on a Theme of Chopin, Op. 22',
#    'Variations on a Theme of Corelli, Op. 42',
#    'Vers la flamme',
#    'Waltzes, Op. 34',
#    'Wedding day at Troldhaugen',
#    'Études Op. 25',
#    'Études Op. 25',
#    'Études Op.10',
#    'Études Op.10']},
#  {'compositor': 'Nicolaus Bruhns',
#   'obra': ['Zärtliche Liebe',
#    'Three Pieces for Orchestra',
#    'Ab Irato',
#    'Adagio in B minor',
#    'Bagatelles, Opus 119',
#    'Bagatelles, Opus 33',
#    'Ballade No.1',
#    'Barcarole Op. 60',
#    'Berceuse',
#    'Coriolan Overture',
#    'Czech Suite',
#    'Fantasy on Hungarian Folk Themes',
#    "Feuilles d'Album",
#    'Funeral March in Memory of Rikard Nordraak',
#    'Fürchte dich nicht',
#    'Grande Tarantelle',
#    'Grande valse brillante',
#    'Hungarian Rhapsody No. 10',
#    'Hungarian Rhapsody No. 13',
#    'Hungarian Rhapsody No. 15',
#    'Hungarian Rhapsody No. 16',
#    'Hungarian Rhapsody No. 18',
#    'Hungarian Rhapsody No. 5',
#    'Hungarian Rhapsody No. 8',
#    "In Nature's Realm",
#    'Les cinq doigts',
#    'Lobet den Herrn, alle Heiden',
#    'Marie-Magdeleine',
#    'Mazurkas, Op. 30',
#    'Mazurkas, Op. 50',
#    'Mazurkas, Op. 63',
#    'Morceaux de Salon, Op. 10',
#    'Nocturne in C minor',
#    'Paganini Variations, Book I',
#    'Preludes Op. 11',
#    'Preludes Op. 11',
#    'Preludes Op. 74',
#    'Preludes Opus 51',
#    'Preludes, Op. 32',
#    'Prélude, Choral et Fugue',
#    'Psalm 42 , Op. 42',
#    'Rhapsodie Espagnole',
#    'Scherzo No. 2',
#    'Scherzo No.3',
#    'Scherzo No.4',
#    'Serenade for Strings in G minor',
#    'Serenata Notturna',
#    'Sigurd Jorsalfar',
#    'Suite for Orchestra in B minor',
#    "Symphonic Poem No.1, Ce qu'on entend sur la montagne",
#    'Syrinx',
#    'The Creatures of Prometheus',
#    'Transcendental Études',
#    'Transcendental Études',
#    'Tönet, ihr Pauken! Erschallet, Trompeten!, BWV 214',
#    'Études Op. 25',
#    'Études Op.10']},
#  {'compositor': 'Nicolaus Bruhns',
#   'obra': ['Rage Over a Lost Penny',
#    'Zärtliche Liebe',
#    'Military Band No. 1',
#    'The Rondo',
#    'Three Pieces for Orchestra',
#    'Ab Irato',
#    'Adagio in B minor',
#    'Bagatelles, Opus 119',
#    'Ballade No.1',
#    'Ballades, Op. 10',
#    'Bamboula, Op. 2',
#    'Barcarole Op. 60',
#    'Berceuse',
#    'Book II',
#    'Capriccio Italien',
#    'Czech Suite',
#    'Die Ideale, S.106',
#    'Dixit Dominus',
#    'Eleven Chorale Preludes, Op. 122',
#    'Estampes',
#    'Fantaisie brillante, Op. 22',
#    'Fantasia and Fugue, BWV 542, G minor',
#    'Fantasy No. 4',
#    'Fantasy on Hungarian Folk Themes',
#    'Faust Overture',
#    'Festklänge, S.101',
#    "Feu d'artifice",
#    "Feuilles d'Album",
#    'French Overture',
#    'Funeral March in Memory of Rikard Nordraak',
#    'Fürchte dich nicht',
#    'Gigue in G major, K. 574',
#    'Grande Tarantelle',
#    'Grande valse brillante',
#    'Hungarian Rhapsody No. 10',
#    'Hungarian Rhapsody No. 11',
#    'Hungarian Rhapsody No. 12',
#    'Hungarian Rhapsody No. 14',
#    'Hungarian Rhapsody No. 16',
#    'Hungarian Rhapsody No. 17',
#    'Hungarian Rhapsody No. 18',
#    'Hungarian Rhapsody No. 3',
#    'Hungarian Rhapsody No. 4',
#    'Hungarian Rhapsody No. 8',
#    'Hungarian Rhapsody No. 9',
#    'Hungarian Rhapsody No.1',
#    'Händelgesellschaft volume 50',
#    'Impromptu Op.51',
#    'Impromptu, Op. 29',
#    'Impromptu, Op. 36',
#    "In Nature's Realm",
#    'In the Steppes of Central Asia',
#    "Jeux d'enfants",
#    'Komm, Jesu, komm!',
#    "L'Art de varier",
#    'Le Mancenillier',
#    'Legends, Op.59',
#    'Les cinq doigts',
#    'Liturgy of St. John Chrysostom',
#    'Lobet den Herrn, alle Heiden',
#    'Mass in C major',
#    'Mazurkas, Op. 30',
#    'Mazurkas, Op. 50',
#    'Mazurkas, Op. 56',
#    'Mazurkas, Op. 63',
#    'Mazurkas, Op. 67',
#    'Mazurkas, Op. 68',
#    'Moments musicaux',
#    'Nocturne in A-flat',
#    'Nocturne in C minor',
#    'Nocturnes Op. Posth. 72',
#    'Othello',
#    'Overture, Scherzo and Finale',
#    'Paganini Variations, Book I',
#    'Papillons',
#    'Peer Gynt Suite Suite No. 1',
#    'Polonaise Op. 44',
#    'Polonaises Op.71',
#    'Polonaises, Op.26',
#    'Polonaises, Op.40',
#    'Preludes Op. 11',
#    'Preludes Op. 11',
#    'Preludes Op. 59',
#    'Preludes Op. 74',
#    'Preludes, Op. 32',
#    'Première rhapsodie',
#    'Psalm 42 , Op. 42',
#    'Rhapsodie Espagnole',
#    'Rhapsodies, Op. 79',
#    'Romance in F major',
#    'Romance in G major',
#    'Rondo Op. 1',
#    'Rondo for Piano No. 3',
#    'Salve Regina',
#    'Scherzo No. 2',
#    'Scherzo No.3',
#    'Scherzo No.4',
#    'Serenade for Strings',
#    'Serenade for Strings',
#    'Serenade for Wind Instruments',
#    'Serenata Notturna',
#    'Shéhérazade',
#    'Shéhérazade, ouverture de féerie',
#    'Sigurd Jorsalfar',
#    'Singet dem Herrn ein neues Lied',
#    'Six Pieces for Piano, Op. 118',
#    'Sonatina in G',
#    'Sonnerie de Ste-Geneviève du Mont-de-Paris',
#    'Stabat Mater',
#    'Suite No. 1 for two pianos',
#    'Suite No. 2 for two pianos',
#    'Suite for Orchestra in B minor',
#    'Suite in D minor, HWV 437',
#    'Symphonic Dances, Op. 64',
#    "Symphonic Poem No.1, Ce qu'on entend sur la montagne",
#    'Symphonies de Beethoven',
#    'Syrinx',
#    'Tapiola',
#    'The Creatures of Prometheus',
#    'The Noon Witch',
#    'The Storm, Op.76',
#    'Transcendental Études',
#    'Transcendental Études',
#    'Transcendental Études',
#    'Transcendental Études',
#    'Tönet, ihr Pauken! Erschallet, Trompeten!, BWV 214',
#    'Valse romantique',
#    'Variation on a Waltz by Diabelli',
#    'Variations in F minor',
#    'Variations on a Theme of Corelli, Op. 42',
#    'Vers la flamme',
#    'Waltzes, Op. 34',
#    'Wedding day at Troldhaugen',
#    'Études Op. 25',
#    'Études Op. 25',
#    'Études Op. 25',
#    'Études Op. 25',
#    'Études Op.10',
#    'Études Op.10']},
#  {'compositor': 'Nicolaus Bruhns',
#   'obra': ['Military Band No. 1',
#    'Three Pieces for Orchestra',
#    'Bagatelles, Opus 33',
#    'Ballades, Op. 10',
#    'Bamboula, Op. 2',
#    'Barcarole Op. 60',
#    'Berceuse',
#    'Book II',
#    'Capriccio Italien',
#    'Carnival Overture',
#    'Coriolan Overture',
#    'Die Ideale, S.106',
#    'Dixit Dominus',
#    'Eleven Chorale Preludes, Op. 122',
#    'Estampes',
#    'Fantaisie brillante, Op. 22',
#    'Fantasy No. 4',
#    'Faust Overture',
#    'Festklänge, S.101',
#    'Gigue in G major, K. 574',
#    'Grande valse brillante',
#    'Hamlet, S.104',
#    'Hungarian Rhapsody No. 11',
#    'Hungarian Rhapsody No. 13',
#    'Hungarian Rhapsody No. 14',
#    'Hungarian Rhapsody No. 3',
#    'Hungarian Rhapsody No. 5',
#    'Hungarian Rhapsody No. 7',
#    'Hungarian Rhapsody No. 8',
#    'Hungarian Rhapsody No. 9',
#    'Hungarian Rhapsody No.1',
#    'Impromptu, Op. 29',
#    'In the Steppes of Central Asia',
#    "Jeux d'enfants",
#    "L'Art de varier",
#    'Le Mancenillier',
#    'Liturgy of St. John Chrysostom',
#    'Lobet den Herrn, alle Heiden',
#    'Mass in C major',
#    'Mazurkas, Op. 30',
#    'Mazurkas, Op. 50',
#    'Mazurkas, Op. 63',
#    'Morceau de salon',
#    'Morceaux de Salon, Op. 10',
#    'Nocturne in A-flat',
#    'Nocturne in C minor',
#    'Nocturnes Op. Posth. 72',
#    'Polonaises Op.71',
#    'Polonaises, Op.40',
#    'Preludes Op. 11',
#    'Preludes Op. 11',
#    'Preludes Op. 11 No. 4',
#    'Preludes Op. 74',
#    'Preludes Opus 51',
#    'Präludium und Fuge über das Thema B-A-C-H',
#    'Prélude, Choral et Fugue',
#    'Psalm 42 , Op. 42',
#    'Romance in F major',
#    'Romance in G major',
#    'Rondo Op. 5',
#    'Rondo for Piano No. 3',
#    'Salve Regina',
#    'Scans of the Bach Gesellschaft edition of the Eight Short Preludes and Fugues',
#    'Scherzo No. 2',
#    "Schubert's Valses Nobles",
#    'Serenade for Strings',
#    'Serenade for Wind Instruments',
#    'Shéhérazade, ouverture de féerie',
#    'Singet dem Herrn ein neues Lied',
#    'Six Pieces for Piano, Op. 118',
#    'Sonatina in F major',
#    'Sonatina in G',
#    "St. Paul's Suite",
#    'Stabat Mater',
#    'Suite No. 1 for two pianos',
#    'Suite No. 2 for two pianos',
#    'Suite for Orchestra in B minor',
#    'Symphonic Dances, Op. 64',
#    'Syrinx',
#    'Tapiola',
#    'The Storm, Op.76',
#    'Tragic Overture',
#    'Transcendental Études',
#    'Transcendental Études',
#    'Valse romantique',
#    'Variations on a Theme of Chopin, Op. 22',
#    'Variations on a Theme of Corelli, Op. 42',
#    'Vers la flamme',
#    'Waltzes, Op. 34',
#    'Wedding day at Troldhaugen',
#    'Études Op. 25',
#    'Études Op. 25',
#    'Études Op.10']},
#  {'compositor': 'Nicolaus Bruhns',
#   'obra': ['Rage Over a Lost Penny',
#    'Zärtliche Liebe',
#    'Military Band No. 1',
#    'The Rondo',
#    'Three Pieces for Orchestra',
#    'Ab Irato',
#    'Adagio in B minor',
#    'Bagatelles, Opus 33',
#    'Ballade No.1',
#    'Ballades, Op. 10',
#    'Bamboula, Op. 2',
#    'Berceuse',
#    'Book II',
#    'Cantatas, BWV 141-150',
#    'Carnival Overture',
#    'Coriolan Overture',
#    'Czech Suite',
#    'Die Ideale, S.106',
#    'Dixit Dominus',
#    'Eleven Chorale Preludes, Op. 122',
#    'Eroica Variations',
#    'Estampes',
#    'Fantaisie brillante, Op. 22',
#    'Fantasia and Fugue, BWV 542, G minor',
#    'Fantasia in D minor',
#    'Fantasy No. 2',
#    'Fantasy on Hungarian Folk Themes',
#    'Festklänge, S.101',
#    "Feu d'artifice",
#    "Feuilles d'Album",
#    'French Overture',
#    'Funeral March in Memory of Rikard Nordraak',
#    'Fürchte dich nicht',
#    'Grande Tarantelle',
#    'Grande valse brillante',
#    'Hungarian Rhapsody No. 12',
#    'Hungarian Rhapsody No. 13',
#    'Hungarian Rhapsody No. 14',
#    'Hungarian Rhapsody No. 16',
#    'Hungarian Rhapsody No. 17',
#    'Hungarian Rhapsody No. 18',
#    'Hungarian Rhapsody No. 3',
#    'Hungarian Rhapsody No. 5',
#    'Hungarian Rhapsody No. 7',
#    'Hungarian Rhapsody No. 8',
#    'Hungarian Rhapsody No. 9',
#    'Hungarian Rhapsody No.1',
#    'Händelgesellschaft volume 50',
#    'Impromptu, Op. 36',
#    "In Nature's Realm",
#    'In the Steppes of Central Asia',
#    "Jeux d'enfants",
#    'Komm, Jesu, komm!',
#    "L'Art de varier",
#    'La Savane',
#    'Legends, Op.59',
#    'Les cinq doigts',
#    'Liturgy of St. John Chrysostom',
#    'Lobet den Herrn, alle Heiden',
#    'Marie-Magdeleine',
#    'Mass in C major',
#    'Mazurkas, Op. 30',
#    'Mazurkas, Op. 50',
#    'Mazurkas, Op. 56',
#    'Mazurkas, Op. 63',
#    'Mazurkas, Op. 67',
#    'Mazurkas, Op. 68',
#    'Moments musicaux',
#    'Morceau de salon',
#    'Morceaux de Salon, Op. 10',
#    'Nocturne in A-flat',
#    'Nocturne in C minor',
#    'Nocturnes Op. Posth. 72',
#    'Othello',
#    'Overture, Scherzo and Finale',
#    'Paganini Variations, Book I',
#    'Papillons',
#    'Peer Gynt Suite Suite No. 1',
#    'Polonaise-Fantasie',
#    'Polonaises Op.71',
#    'Polonaises, Op.26',
#    'Polonaises, Op.40',
#    'Preludes Op. 11',
#    'Preludes Op. 11',
#    'Preludes Op. 11',
#    'Preludes Op. 11 No. 4',
#    'Preludes Op. 49',
#    'Preludes Op. 74',
#    'Preludes Opus 51',
#    'Preludes, Op. 32',
#    'Prince Rostislav',
#    'Prélude, Choral et Fugue',
#    'Psalm 42 , Op. 42',
#    'Rhapsodie Espagnole',
#    'Rhapsodies, Op. 79',
#    'Romance in G major',
#    'Rondo Op. 1',
#    'Rondo Op. 5',
#    'Rondo for Piano No. 3',
#    'Scans of the Bach Gesellschaft edition of the Eight Short Preludes and Fugues',
#    'Scherzo No. 2',
#    'Scherzo No.3',
#    'Scherzo No.4',
#    "Schubert's Valses Nobles",
#    'Serenade for Strings',
#    'Serenade for Strings',
#    'Serenade for Strings in G minor',
#    'Serenade for Wind Instruments',
#    'Serenata Notturna',
#    'Shéhérazade',
#    'Shéhérazade, ouverture de féerie',
#    'Sigurd Jorsalfar',
#    'Singet dem Herrn ein neues Lied',
#    'Six Pieces for Piano, Op. 118',
#    'Sonatas and Partitas for Solo Violin',
#    'Sonatina in F major',
#    'Sonatina in G',
#    'Sonnerie de Ste-Geneviève du Mont-de-Paris',
#    "St. Paul's Suite",
#    'Stabat Mater',
#    'Suite No. 1 for two pianos',
#    'Suite for Orchestra in B minor',
#    'Suite in D minor, HWV 437',
#    'Symphonic Dances, Op. 64',
#    "Symphonic Poem No.1, Ce qu'on entend sur la montagne",
#    'Symphonies de Beethoven',
#    'Syrinx',
#    'The Creatures of Prometheus',
#    'The Storm, Op.76',
#    'Transcendental Études',
#    'Transcendental Études',
#    'Transcendental Études',
#    'Tönet, ihr Pauken! Erschallet, Trompeten!, BWV 214',
#    'Valse romantique',
#    'Valses Sentimentales',
#    'Variation on a Waltz by Diabelli',
#    'Variations on a Theme of Chopin, Op. 22',
#    'Variations on a Theme of Corelli, Op. 42',
#    'Vers la flamme',
#    'Waltzes, Op. 34',
#    'Wedding day at Troldhaugen',
#    'Études Op. 25',
#    'Études Op. 25',
#    'Études Op. 25',
#    'Études Op. 25',
#    'Études Op.10',
#    'Études Op.10']},
#  {'compositor': 'Nicolaus Bruhns',
#   'obra': ['Rage Over a Lost Penny',
#    'Military Band No. 1',
#    'Three Pieces for Orchestra',
#    'Adagio in B minor',
#    'Bagatelles, Opus 33',
#    'Berceuse',
#    'Book II',
#    'Carnival Overture',
#    'Czech Suite',
#    'Estampes',
#    'Fantasy No. 2',
#    'Festklänge, S.101',
#    "Feu d'artifice",
#    'French Overture',
#    'Grande Tarantelle',
#    'Grande valse brillante',
#    'Hungarian Rhapsody No. 15',
#    'Hungarian Rhapsody No. 17',
#    'Hungarian Rhapsody No. 18',
#    'Hungarian Rhapsody No. 7',
#    'Hungarian Rhapsody No. 9',
#    'Händelgesellschaft volume 50',
#    'Impromptu, Op. 29',
#    'In the Steppes of Central Asia',
#    "Jeux d'enfants",
#    'Komm, Jesu, komm!',
#    'Legends, Op.59',
#    'Liturgy of St. John Chrysostom',
#    'Mass in C major',
#    'Morceau de salon',
#    'Morceaux de Salon, Op. 10',
#    'Preludes Op. 11',
#    'Preludes Op. 11',
#    'Preludes Op. 11 No. 4',
#    'Romance in G major',
#    'Rondo Op. 1',
#    'Rondo Op. 5',
#    'Rondo for Piano No. 3',
#    'Scans of the Bach Gesellschaft edition of the Eight Short Preludes and Fugues',
#    "Schubert's Valses Nobles",
#    'Serenade for Strings',
#    'Serenade for Strings',
#    'Serenata Notturna',
#    'Shéhérazade, ouverture de féerie',
#    'Sigurd Jorsalfar',
#    'Six Pieces for Piano, Op. 118',
#    'Sonatas and Partitas for Solo Violin',
#    'Sonatina in F major',
#    'Sonatina in G',
#    'Sonnerie de Ste-Geneviève du Mont-de-Paris',
#    "St. Paul's Suite",
#    "Symphonic Poem No.1, Ce qu'on entend sur la montagne",
#    'Symphonies de Beethoven',
#    'Syrinx',
#    'The Storm, Op.76',
#    'Tönet, ihr Pauken! Erschallet, Trompeten!, BWV 214',
#    'Valse romantique',
#    'Variations in F minor',
#    'Études Op. 25',
#    'Études Op. 25',
#    'Études Op.10']},
#  {'compositor': 'Nicolaus Bruhns',
#   'obra': ['Rage Over a Lost Penny',
#    'Military Band No. 1',
#    'The Rondo',
#    'Three Pieces for Orchestra',
#    'Adagio in B minor',
#    'Ballades, Op. 10',
#    'Bamboula, Op. 2',
#    'Berceuse',
#    'Book II',
#    'Cantatas, BWV 141-150',
#    'Carnival Overture',
#    'Czech Suite',
#    'Die Ideale, S.106',
#    'Eleven Chorale Preludes, Op. 122',
#    'Eroica Variations',
#    'Fantasia in D minor',
#    'Fantasy No. 2',
#    'Fantasy on Hungarian Folk Themes',
#    "Feu d'artifice",
#    "Feuilles d'Album",
#    'Funeral March in Memory of Rikard Nordraak',
#    'Grande Tarantelle',
#    'Hamlet, S.104',
#    'Hungarian Rhapsody No. 17',
#    'Hungarian Rhapsody No. 18',
#    'Hungarian Rhapsody No. 7',
#    'Hungarian Rhapsody No. 8',
#    'Hungarian Rhapsody No. 9',
#    'Händelgesellschaft volume 50',
#    'Impromptu Op.51',
#    'Impromptu, Op. 36',
#    'In the Steppes of Central Asia',
#    'Lobet den Herrn, alle Heiden',
#    'Mazurkas, Op. 50',
#    'Mazurkas, Op. 67',
#    'Mazurkas, Op. 68',
#    'Moments musicaux',
#    'Morceau de salon',
#    'Nocturne in A-flat',
#    'Nocturne in C minor',
#    'Nocturnes Op. Posth. 72',
#    'Paganini Variations, Book I',
#    'Papillons',
#    'Polonaise Op. 44',
#    'Polonaises, Op.26',
#    'Polonaises, Op.40',
#    'Preludes Op. 11',
#    'Preludes Op. 11 No. 4',
#    'Preludes Op. 74',
#    'Präludium und Fuge über das Thema B-A-C-H',
#    'Psalm 42 , Op. 42',
#    'Scans of the Bach Gesellschaft edition of the Eight Short Preludes and Fugues',
#    'Scherzo No.3',
#    'Scherzo No.4',
#    "Schubert's Valses Nobles",
#    'Serenade for Strings',
#    'Serenade for Wind Instruments',
#    'Singet dem Herrn ein neues Lied',
#    'Sonatas and Partitas for Solo Violin',
#    'Sonatina in F major',
#    'Sonatina in G',
#    'Sonnerie de Ste-Geneviève du Mont-de-Paris',
#    "St. Paul's Suite",
#    'Stabat Mater',
#    'Suite No. 1 for two pianos',
#    'Suite in D minor, HWV 437',
#    "Symphonic Poem No.1, Ce qu'on entend sur la montagne",
#    'Symphonies de Beethoven',
#    'Syrinx',
#    'The Creatures of Prometheus',
#    'Tragic Overture',
#    'Transcendental Études',
#    'Transcendental Études',
#    'Transcendental Études',
#    'Tönet, ihr Pauken! Erschallet, Trompeten!, BWV 214',
#    'Valses Sentimentales',
#    'Variations in F minor',
#    'Variations on a Theme of Corelli, Op. 42',
#    'Vers la flamme',
#    'Wedding day at Troldhaugen',
#    'Études Op. 25',
#    'Études Op. 25',
#    'Études Op.10',
#    'Études Op.10']},
#  {'compositor': 'Nicolaus Bruhns',
#   'obra': ['Rage Over a Lost Penny',
#    'Zärtliche Liebe',
#    'Military Band No. 1',
#    'The Rondo',
#    'Three Pieces for Orchestra',
#    'Ab Irato',
#    'Adagio in B minor',
#    'Bagatelles, Opus 119',
#    'Bagatelles, Opus 33',
#    'Ballade No.1',
#    'Ballades, Op. 10',
#    'Bamboula, Op. 2',
#    'Barcarole Op. 60',
#    'Berceuse',
#    'Book II',
#    'Cantatas, BWV 141-150',
#    'Capriccio Italien',
#    'Carnival Overture',
#    'Coriolan Overture',
#    'Czech Suite',
#    'Die Ideale, S.106',
#    'Dixit Dominus',
#    'Eleven Chorale Preludes, Op. 122',
#    'Eroica Variations',
#    'Estampes',
#    'Fantaisie brillante, Op. 22',
#    'Fantasia and Fugue, BWV 542, G minor',
#    'Fantasia in D minor',
#    'Fantasy No. 2',
#    'Fantasy No. 4',
#    'Fantasy on Hungarian Folk Themes',
#    'Faust Overture',
#    'Festklänge, S.101',
#    "Feu d'artifice",
#    "Feuilles d'Album",
#    'French Overture',
#    'Funeral March in Memory of Rikard Nordraak',
#    'Fürchte dich nicht',
#    'Gigue in G major, K. 574',
#    'Grande Tarantelle',
#    'Grande valse brillante',
#    'Hamlet, S.104',
#    'Hungarian Rhapsody No. 10',
#    'Hungarian Rhapsody No. 11',
#    'Hungarian Rhapsody No. 12',
#    'Hungarian Rhapsody No. 13',
#    'Hungarian Rhapsody No. 14',
#    'Hungarian Rhapsody No. 15',
#    'Hungarian Rhapsody No. 16',
#    'Hungarian Rhapsody No. 17',
#    'Hungarian Rhapsody No. 18',
#    'Hungarian Rhapsody No. 3',
#    'Hungarian Rhapsody No. 4',
#    'Hungarian Rhapsody No. 5',
#    'Hungarian Rhapsody No. 7',
#    'Hungarian Rhapsody No. 8',
#    'Hungarian Rhapsody No. 9',
#    'Hungarian Rhapsody No.1',
#    'Händelgesellschaft volume 50',
#    'Impromptu Op.51',
#    'Impromptu, Op. 29',
#    'Impromptu, Op. 36',
#    "In Nature's Realm",
#    'In the Steppes of Central Asia',
#    "Jeux d'enfants",
#    'Komm, Jesu, komm!',
#    "L'Art de varier",
#    'La Savane',
#    'Le Mancenillier',
#    'Legends, Op.59',
#    'Les cinq doigts',
#    'Liturgy of St. John Chrysostom',
#    'Lobet den Herrn, alle Heiden',
#    'Marie-Magdeleine',
#    'Mass in C major',
#    'Mazurkas, Op. 30',
#    'Mazurkas, Op. 50',
#    'Mazurkas, Op. 56',
#    'Mazurkas, Op. 63',
#    'Mazurkas, Op. 67',
#    'Mazurkas, Op. 68',
#    'Moments musicaux',
#    'Morceau de salon',
#    'Morceaux de Salon, Op. 10',
#    'Nocturne in A-flat',
#    'Nocturne in C minor',
#    'Nocturnes Op. Posth. 72',
#    'Othello',
#    'Overture, Scherzo and Finale',
#    'Paganini Variations, Book I',
#    'Papillons',
#    'Peer Gynt Suite Suite No. 1',
#    'Polonaise Op. 44',
#    'Polonaise-Fantasie',
#    'Polonaises Op.71',
#    'Polonaises, Op.26',
#    'Polonaises, Op.40',
#    'Preludes Op. 11',
#    'Preludes Op. 11',
#    'Preludes Op. 11',
#    'Preludes Op. 11 No. 4',
#    'Preludes Op. 49',
#    'Preludes Op. 59',
#    'Preludes Op. 74',
#    'Preludes Opus 51',
#    'Preludes, Op. 32',
#    'Première rhapsodie',
#    'Prince Rostislav',
#    'Präludium und Fuge über das Thema B-A-C-H',
#    'Prélude, Choral et Fugue',
#    'Psalm 42 , Op. 42',
#    'Rhapsodie Espagnole',
#    'Rhapsodies, Op. 79',
#    'Romance in F major',
#    'Romance in G major',
#    'Rondo Op. 1',
#    'Rondo Op. 5',
#    'Rondo for Piano No. 3',
#    'Salve Regina',
#    'Scans of the Bach Gesellschaft edition of the Eight Short Preludes and Fugues',
#    'Scherzo No. 2',
#    'Scherzo No.3',
#    'Scherzo No.4',
#    "Schubert's Valses Nobles",
#    'Serenade for Strings',
#    'Serenade for Strings',
#    'Serenade for Strings in G minor',
#    'Serenade for Wind Instruments',
#    'Serenata Notturna',
#    'Shéhérazade',
#    'Shéhérazade, ouverture de féerie',
#    'Sigurd Jorsalfar',
#    'Singet dem Herrn ein neues Lied',
#    'Six Pieces for Piano, Op. 118',
#    'Sonatas and Partitas for Solo Violin',
#    'Sonatina in F major',
#    'Sonatina in G',
#    'Sonnerie de Ste-Geneviève du Mont-de-Paris',
#    "St. Paul's Suite",
#    'Stabat Mater',
#    'Suite No. 1 for two pianos',
#    'Suite No. 2 for two pianos',
#    'Suite for Orchestra in B minor',
#    'Suite in D minor, HWV 437',
#    'Symphonic Dances, Op. 64',
#    "Symphonic Poem No.1, Ce qu'on entend sur la montagne",
#    'Symphonies de Beethoven',
#    'Syrinx',
#    'Tapiola',
#    'The Creatures of Prometheus',
#    'The Noon Witch',
#    'The Storm, Op.76',
#    'Tragic Overture',
#    'Transcendental Études',
#    'Transcendental Études',
#    'Transcendental Études',
#    'Transcendental Études',
#    'Tönet, ihr Pauken! Erschallet, Trompeten!, BWV 214',
#    'Valse romantique',
#    'Valses Sentimentales',
#    'Variation on a Waltz by Diabelli',
#    'Variations in F minor',
#    'Variations on a Theme of Chopin, Op. 22',
#    'Variations on a Theme of Corelli, Op. 42',
#    'Vers la flamme',
#    'Waltzes, Op. 34',
#    'Wedding day at Troldhaugen',
#    'Études Op. 25',
#    'Études Op. 25',
#    'Études Op. 25',
#    'Études Op. 25',
#    'Études Op. 25',
#    'Études Op.10',
#    'Études Op.10']},
#  {'compositor': 'Nicolaus Bruhns',
#   'obra': ['The Rondo',
#    'Three Pieces for Orchestra',
#    'Berceuse',
#    'Coriolan Overture',
#    'Eleven Chorale Preludes, Op. 122',
#    'Fantasia and Fugue, BWV 542, G minor',
#    'Fantasy No. 4',
#    'Hungarian Rhapsody No. 15',
#    'Hungarian Rhapsody No. 4',
#    'Hungarian Rhapsody No. 5',
#    'Hungarian Rhapsody No. 7',
#    'Händelgesellschaft volume 50',
#    'Impromptu, Op. 29',
#    'Impromptu, Op. 36',
#    "Jeux d'enfants",
#    'La Savane',
#    'Mazurkas, Op. 30',
#    'Mazurkas, Op. 63',
#    'Mazurkas, Op. 67',
#    'Moments musicaux',
#    'Morceau de salon',
#    'Paganini Variations, Book I',
#    'Papillons',
#    'Polonaise-Fantasie',
#    'Preludes Op. 11',
#    'Preludes Op. 11 No. 4',
#    'Preludes Opus 51',
#    'Prince Rostislav',
#    'Romance in F major',
#    'Scans of the Bach Gesellschaft edition of the Eight Short Preludes and Fugues',
#    'Scherzo No.4',
#    'Serenade for Strings in G minor',
#    'Shéhérazade, ouverture de féerie',
#    'Sonatina in F major',
#    "St. Paul's Suite",
#    'Stabat Mater',
#    'Suite in D minor, HWV 437',
#    "Symphonic Poem No.1, Ce qu'on entend sur la montagne",
#    'Tapiola',
#    'Études Op.10',
#    'Études Op.10']},
#  {'compositor': 'Nicolaus Bruhns',
#   'obra': ['Rage Over a Lost Penny',
#    'Military Band No. 1',
#    'The Rondo',
#    'Three Pieces for Orchestra',
#    'Adagio in B minor',
#    'Bagatelles, Opus 119',
#    'Ballade No.1',
#    'Ballades, Op. 10',
#    'Barcarole Op. 60',
#    'Book II',
#    'Cantatas, BWV 141-150',
#    'Carnival Overture',
#    'Coriolan Overture',
#    'Dixit Dominus',
#    'Eleven Chorale Preludes, Op. 122',
#    'Eroica Variations',
#    'Estampes',
#    'Fantaisie brillante, Op. 22',
#    'Fantasia and Fugue, BWV 542, G minor',
#    'Fantasia in D minor',
#    'Fantasy No. 2',
#    'Fantasy on Hungarian Folk Themes',
#    'Faust Overture',
#    'Festklänge, S.101',
#    "Feu d'artifice",
#    "Feuilles d'Album",
#    'French Overture',
#    'Funeral March in Memory of Rikard Nordraak',
#    'Fürchte dich nicht',
#    'Grande Tarantelle',
#    'Hamlet, S.104',
#    'Hungarian Rhapsody No. 10',
#    'Hungarian Rhapsody No. 12',
#    'Hungarian Rhapsody No. 13',
#    'Hungarian Rhapsody No. 14',
#    'Hungarian Rhapsody No. 15',
#    'Hungarian Rhapsody No. 16',
#    'Hungarian Rhapsody No. 17',
#    'Hungarian Rhapsody No. 3',
#    'Hungarian Rhapsody No. 4',
#    'Hungarian Rhapsody No. 5',
#    'Hungarian Rhapsody No. 7',
#    'Hungarian Rhapsody No. 8',
#    'Hungarian Rhapsody No. 9',
#    'Händelgesellschaft volume 50',
#    'Impromptu, Op. 36',
#    "In Nature's Realm",
#    'In the Steppes of Central Asia',
#    "Jeux d'enfants",
#    'Komm, Jesu, komm!',
#    'La Savane',
#    'Le Mancenillier',
#    'Legends, Op.59',
#    'Les cinq doigts',
#    'Liturgy of St. John Chrysostom',
#    'Lobet den Herrn, alle Heiden',
#    'Marie-Magdeleine',
#    'Mass in C major',
#    'Mazurkas, Op. 50',
#    'Mazurkas, Op. 56',
#    'Mazurkas, Op. 67',
#    'Nocturne in A-flat',
#    'Nocturne in C minor',
#    'Nocturnes Op. Posth. 72',
#    'Othello',
#    'Overture, Scherzo and Finale',
#    'Peer Gynt Suite Suite No. 1',
#    'Polonaise-Fantasie',
#    'Polonaises Op.71',
#    'Polonaises, Op.26',
#    'Preludes Op. 11',
#    'Preludes Op. 11',
#    'Preludes Op. 11',
#    'Preludes Op. 11 No. 4',
#    'Preludes Op. 49',
#    'Preludes Op. 74',
#    'Preludes Opus 51',
#    'Prince Rostislav',
#    'Präludium und Fuge über das Thema B-A-C-H',
#    'Prélude, Choral et Fugue',
#    'Psalm 42 , Op. 42',
#    'Rhapsodie Espagnole',
#    'Romance in G major',
#    'Rondo Op. 1',
#    'Salve Regina',
#    'Scherzo No. 2',
#    'Scherzo No.4',
#    "Schubert's Valses Nobles",
#    'Serenade for Strings',
#    'Serenade for Strings',
#    'Serenade for Strings in G minor',
#    'Shéhérazade',
#    'Shéhérazade, ouverture de féerie',
#    'Six Pieces for Piano, Op. 118',
#    'Sonatas and Partitas for Solo Violin',
#    'Sonatina in F major',
#    'Sonatina in G',
#    'Sonnerie de Ste-Geneviève du Mont-de-Paris',
#    'Stabat Mater',
#    'Suite No. 1 for two pianos',
#    'Suite No. 2 for two pianos',
#    'Suite for Orchestra in B minor',
#    'Suite in D minor, HWV 437',
#    'Symphonies de Beethoven',
#    'Syrinx',
#    'The Creatures of Prometheus',
#    'The Storm, Op.76',
#    'Tragic Overture',
#    'Transcendental Études',
#    'Transcendental Études',
#    'Transcendental Études',
#    'Tönet, ihr Pauken! Erschallet, Trompeten!, BWV 214',
#    'Valses Sentimentales',
#    'Variations in F minor',
#    'Variations on a Theme of Chopin, Op. 22',
#    'Variations on a Theme of Corelli, Op. 42',
#    'Waltzes, Op. 34',
#    'Wedding day at Troldhaugen',
#    'Études Op. 25',
#    'Études Op. 25',
#    'Études Op.10',
#    'Études Op.10']},
#  {'compositor': 'Nicolaus Bruhns',
#   'obra': ['Rage Over a Lost Penny',
#    'Military Band No. 1',
#    'Three Pieces for Orchestra',
#    'Adagio in B minor',
#    'Bagatelles, Opus 33',
#    'Berceuse',
#    'Book II',
#    'Carnival Overture',
#    'Czech Suite',
#    'Estampes',
#    'Fantasy No. 2',
#    'Festklänge, S.101',
#    "Feu d'artifice",
#    'French Overture',
#    'Grande Tarantelle',
#    'Grande valse brillante',
#    'Hungarian Rhapsody No. 15',
#    'Hungarian Rhapsody No. 17',
#    'Hungarian Rhapsody No. 18',
#    'Hungarian Rhapsody No. 7',
#    'Hungarian Rhapsody No. 9',
#    'Händelgesellschaft volume 50',
#    'Impromptu, Op. 29',
#    'In the Steppes of Central Asia',
#    "Jeux d'enfants",
#    'Komm, Jesu, komm!',
#    'Legends, Op.59',
#    'Liturgy of St. John Chrysostom',
#    'Mass in C major',
#    'Morceau de salon',
#    'Morceaux de Salon, Op. 10',
#    'Preludes Op. 11',
#    'Preludes Op. 11',
#    'Preludes Op. 11 No. 4',
#    'Romance in G major',
#    'Rondo Op. 1',
#    'Rondo Op. 5',
#    'Rondo for Piano No. 3',
#    'Scans of the Bach Gesellschaft edition of the Eight Short Preludes and Fugues',
#    "Schubert's Valses Nobles",
#    'Serenade for Strings',
#    'Serenade for Strings',
#    'Serenata Notturna',
#    'Shéhérazade, ouverture de féerie',
#    'Sigurd Jorsalfar',
#    'Six Pieces for Piano, Op. 118',
#    'Sonatas and Partitas for Solo Violin',
#    'Sonatina in F major',
#    'Sonatina in G',
#    'Sonnerie de Ste-Geneviève du Mont-de-Paris',
#    "St. Paul's Suite",
#    "Symphonic Poem No.1, Ce qu'on entend sur la montagne",
#    'Symphonies de Beethoven',
#    'Syrinx',
#    'The Storm, Op.76',
#    'Tönet, ihr Pauken! Erschallet, Trompeten!, BWV 214',
#    'Valse romantique',
#    'Variations in F minor',
#    'Études Op. 25',
#    'Études Op. 25',
#    'Études Op.10']},
#  {'compositor': 'Nicolaus Bruhns',
#   'obra': ['Rage Over a Lost Penny',
#    'Zärtliche Liebe',
#    'Three Pieces for Orchestra',
#    'Ab Irato',
#    'Bagatelles, Opus 119',
#    'Bagatelles, Opus 33',
#    'Ballade No.1',
#    'Bamboula, Op. 2',
#    'Barcarole Op. 60',
#    'Berceuse',
#    'Capriccio Italien',
#    'Coriolan Overture',
#    'Die Ideale, S.106',
#    'Estampes',
#    'Fantasy No. 4',
#    'Faust Overture',
#    "Feu d'artifice",
#    'Fürchte dich nicht',
#    'Grande Tarantelle',
#    'Grande valse brillante',
#    'Hamlet, S.104',
#    'Hungarian Rhapsody No. 10',
#    'Hungarian Rhapsody No. 11',
#    'Hungarian Rhapsody No. 12',
#    'Hungarian Rhapsody No. 15',
#    'Hungarian Rhapsody No. 16',
#    'Hungarian Rhapsody No. 17',
#    'Hungarian Rhapsody No. 4',
#    'Hungarian Rhapsody No. 5',
#    'Hungarian Rhapsody No. 9',
#    'Hungarian Rhapsody No.1',
#    'Impromptu Op.51',
#    'Impromptu, Op. 29',
#    "In Nature's Realm",
#    "L'Art de varier",
#    'Liturgy of St. John Chrysostom',
#    'Marie-Magdeleine',
#    'Mazurkas, Op. 30',
#    'Mazurkas, Op. 63',
#    'Mazurkas, Op. 68',
#    'Morceaux de Salon, Op. 10',
#    'Overture, Scherzo and Finale',
#    'Polonaise Op. 44',
#    'Polonaises, Op.40',
#    'Preludes Op. 11',
#    'Preludes Op. 11',
#    'Preludes Op. 59',
#    'Preludes Opus 51',
#    'Preludes, Op. 32',
#    'Première rhapsodie',
#    'Präludium und Fuge über das Thema B-A-C-H',
#    'Rhapsodie Espagnole',
#    'Romance in F major',
#    'Rondo Op. 5',
#    'Salve Regina',
#    'Scherzo No.3',
#    'Scherzo No.4',
#    'Serenade for Strings in G minor',
#    'Serenata Notturna',
#    'Sigurd Jorsalfar',
#    'Sonnerie de Ste-Geneviève du Mont-de-Paris',
#    'Suite No. 2 for two pianos',
#    'Symphonic Dances, Op. 64',
#    'Symphonies de Beethoven',
#    'Syrinx',
#    'Tapiola',
#    'The Noon Witch',
#    'Tragic Overture',
#    'Transcendental Études',
#    'Variations on a Theme of Chopin, Op. 22',
#    'Variations on a Theme of Corelli, Op. 42',
#    'Wedding day at Troldhaugen',
#    'Études Op. 25',
#    'Études Op. 25',
#    'Études Op. 25',
#    'Études Op. 25',
#    'Études Op.10']},
#  {'compositor': 'Nicolaus Bruhns',
#   'obra': ['Rage Over a Lost Penny',
#    'Zärtliche Liebe',
#    'Military Band No. 1',
#    'The Rondo',
#    'Three Pieces for Orchestra',
#    'Ab Irato',
#    'Adagio in B minor',
#    'Bagatelles, Opus 119',
#    'Ballade No.1',
#    'Bamboula, Op. 2',
#    'Berceuse',
#    'Book II',
#    'Cantatas, BWV 141-150',
#    'Capriccio Italien',
#    'Coriolan Overture',
#    'Czech Suite',
#    'Die Ideale, S.106',
#    'Dixit Dominus',
#    'Eleven Chorale Preludes, Op. 122',
#    'Eroica Variations',
#    'Estampes',
#    'Fantaisie brillante, Op. 22',
#    'Fantasia in D minor',
#    'Fantasy No. 2',
#    'Fantasy No. 4',
#    'Faust Overture',
#    'Festklänge, S.101',
#    "Feu d'artifice",
#    'Fürchte dich nicht',
#    'Grande Tarantelle',
#    'Grande valse brillante',
#    'Hungarian Rhapsody No. 10',
#    'Hungarian Rhapsody No. 11',
#    'Hungarian Rhapsody No. 12',
#    'Hungarian Rhapsody No. 13',
#    'Hungarian Rhapsody No. 16',
#    'Hungarian Rhapsody No. 17',
#    'Hungarian Rhapsody No. 18',
#    'Hungarian Rhapsody No. 3',
#    'Hungarian Rhapsody No. 5',
#    'Hungarian Rhapsody No. 8',
#    'Hungarian Rhapsody No. 9',
#    'Hungarian Rhapsody No.1',
#    'Händelgesellschaft volume 50',
#    'Impromptu, Op. 29',
#    "In Nature's Realm",
#    'In the Steppes of Central Asia',
#    "L'Art de varier",
#    'La Savane',
#    'Liturgy of St. John Chrysostom',
#    'Lobet den Herrn, alle Heiden',
#    'Marie-Magdeleine',
#    'Mass in C major',
#    'Mazurkas, Op. 30',
#    'Mazurkas, Op. 50',
#    'Mazurkas, Op. 63',
#    'Mazurkas, Op. 68',
#    'Moments musicaux',
#    'Morceau de salon',
#    'Nocturne in A-flat',
#    'Nocturnes Op. Posth. 72',
#    'Overture, Scherzo and Finale',
#    'Paganini Variations, Book I',
#    'Papillons',
#    'Peer Gynt Suite Suite No. 1',
#    'Polonaise-Fantasie',
#    'Polonaises Op.71',
#    'Polonaises, Op.26',
#    'Polonaises, Op.40',
#    'Preludes Op. 11',
#    'Preludes Op. 59',
#    'Preludes Op. 74',
#    'Preludes Opus 51',
#    'Preludes, Op. 32',
#    'Première rhapsodie',
#    'Prince Rostislav',
#    'Prélude, Choral et Fugue',
#    'Psalm 42 , Op. 42',
#    'Rhapsodie Espagnole',
#    'Rhapsodies, Op. 79',
#    'Romance in F major',
#    'Romance in G major',
#    'Rondo Op. 5',
#    'Rondo for Piano No. 3',
#    'Salve Regina',
#    'Scans of the Bach Gesellschaft edition of the Eight Short Preludes and Fugues',
#    'Scherzo No. 2',
#    'Scherzo No.3',
#    'Scherzo No.4',
#    'Serenade for Strings',
#    'Serenade for Strings in G minor',
#    'Serenade for Wind Instruments',
#    'Serenata Notturna',
#    'Shéhérazade',
#    'Sigurd Jorsalfar',
#    'Singet dem Herrn ein neues Lied',
#    'Six Pieces for Piano, Op. 118',
#    'Sonatas and Partitas for Solo Violin',
#    'Sonatina in G',
#    'Sonnerie de Ste-Geneviève du Mont-de-Paris',
#    "St. Paul's Suite",
#    'Stabat Mater',
#    'Suite No. 1 for two pianos',
#    'Suite No. 2 for two pianos',
#    'Suite for Orchestra in B minor',
#    'Suite in D minor, HWV 437',
#    'Symphonic Dances, Op. 64',
#    "Symphonic Poem No.1, Ce qu'on entend sur la montagne",
#    'Symphonies de Beethoven',
#    'Syrinx',
#    'Tapiola',
#    'The Creatures of Prometheus',
#    'The Noon Witch',
#    'The Storm, Op.76',
#    'Transcendental Études',
#    'Transcendental Études',
#    'Transcendental Études',
#    'Tönet, ihr Pauken! Erschallet, Trompeten!, BWV 214',
#    'Valse romantique',
#    'Valses Sentimentales',
#    'Variation on a Waltz by Diabelli',
#    'Variations in F minor',
#    'Variations on a Theme of Corelli, Op. 42',
#    'Vers la flamme',
#    'Waltzes, Op. 34',
#    'Wedding day at Troldhaugen',
#    'Études Op. 25',
#    'Études Op. 25',
#    'Études Op. 25',
#    'Études Op.10',
#    'Études Op.10']},
#  {'compositor': 'Nicolaus Bruhns',
#   'obra': ['Rage Over a Lost Penny',
#    'Military Band No. 1',
#    'The Rondo',
#    'Three Pieces for Orchestra',
#    'Adagio in B minor',
#    'Ballades, Op. 10',
#    'Bamboula, Op. 2',
#    'Berceuse',
#    'Book II',
#    'Cantatas, BWV 141-150',
#    'Carnival Overture',
#    'Czech Suite',
#    'Die Ideale, S.106',
#    'Eleven Chorale Preludes, Op. 122',
#    'Eroica Variations',
#    'Fantasia in D minor',
#    'Fantasy No. 2',
#    'Fantasy on Hungarian Folk Themes',
#    "Feu d'artifice",
#    "Feuilles d'Album",
#    'Funeral March in Memory of Rikard Nordraak',
#    'Grande Tarantelle',
#    'Hamlet, S.104',
#    'Hungarian Rhapsody No. 17',
#    'Hungarian Rhapsody No. 18',
#    'Hungarian Rhapsody No. 7',
#    'Hungarian Rhapsody No. 8',
#    'Hungarian Rhapsody No. 9',
#    'Händelgesellschaft volume 50',
#    'Impromptu Op.51',
#    'Impromptu, Op. 36',
#    'In the Steppes of Central Asia',
#    'Lobet den Herrn, alle Heiden',
#    'Mazurkas, Op. 50',
#    'Mazurkas, Op. 67',
#    'Mazurkas, Op. 68',
#    'Moments musicaux',
#    'Morceau de salon',
#    'Nocturne in A-flat',
#    'Nocturne in C minor',
#    'Nocturnes Op. Posth. 72',
#    'Paganini Variations, Book I',
#    'Papillons',
#    'Polonaise Op. 44',
#    'Polonaises, Op.26',
#    'Polonaises, Op.40',
#    'Preludes Op. 11',
#    'Preludes Op. 11 No. 4',
#    'Preludes Op. 74',
#    'Präludium und Fuge über das Thema B-A-C-H',
#    'Psalm 42 , Op. 42',
#    'Scans of the Bach Gesellschaft edition of the Eight Short Preludes and Fugues',
#    'Scherzo No.3',
#    'Scherzo No.4',
#    "Schubert's Valses Nobles",
#    'Serenade for Strings',
#    'Serenade for Wind Instruments',
#    'Singet dem Herrn ein neues Lied',
#    'Sonatas and Partitas for Solo Violin',
#    'Sonatina in F major',
#    'Sonatina in G',
#    'Sonnerie de Ste-Geneviève du Mont-de-Paris',
#    "St. Paul's Suite",
#    'Stabat Mater',
#    'Suite No. 1 for two pianos',
#    'Suite in D minor, HWV 437',
#    "Symphonic Poem No.1, Ce qu'on entend sur la montagne",
#    'Symphonies de Beethoven',
#    'Syrinx',
#    'The Creatures of Prometheus',
#    'Tragic Overture',
#    'Transcendental Études',
#    'Transcendental Études',
#    'Transcendental Études',
#    'Tönet, ihr Pauken! Erschallet, Trompeten!, BWV 214',
#    'Valses Sentimentales',
#    'Variations in F minor',
#    'Variations on a Theme of Corelli, Op. 42',
#    'Vers la flamme',
#    'Wedding day at Troldhaugen',
#    'Études Op. 25',
#    'Études Op. 25',
#    'Études Op.10',
#    'Études Op.10']}]
